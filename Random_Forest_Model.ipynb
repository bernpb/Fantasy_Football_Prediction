# %% [markdown]
# ### Import packages
#
# Import of the packages that will be needed for the project.  This includes packages for data manipulation, sklearn modules and custom functions.

# %%
import pandas as pd
import numpy as np
import pickle

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, RobustScaler, StandardScaler, FunctionTransformer

from Project_Functions import offensive_contribution, trailing_stats_mean, tier_maker, get_tiers, get_touchdowns, stats_for_trailing

# %%
import warnings
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action = 'ignore',
                     category = SettingWithCopyWarning)

# %% [markdown]
# ### Import Data
#
# Let's import the dataframe that we will be using for modelling

# %%
data = pd.read_csv('Data/weekly_data.csv')
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1    GameKey  PlayerID  Season             GameDate  \
# 0           0             0  201810122      8283    2018  2018-09-09T13:00:00
# 1           1             1  201810122     18878    2018  2018-09-09T13:00:00
# 2           2             2  201810122      7242    2018  2018-09-09T13:00:00
# 3           4             4  201810129     18082    2018  2018-09-09T16:05:00
# 4           5             5  201810108     18983    2018  2018-09-09T13:00:00
#
#    Week Team Opponent HomeOrAway  ...  FieldGoalsMade40to49  \
# 0     1   TB       NO       AWAY  ...                   0.0
# 1     1   NO       TB       HOME  ...                   0.0
# 2     1   NO       TB       HOME  ...                   0.0
# 3     1   KC      LAC       AWAY  ...                   0.0
# 4     1  PIT      CLE       AWAY  ...                   0.0
#
#   FieldGoalsMade50Plus InjuryStatus  MatchString  HomeTeam  HomePoints  \
# 0                  0.0          NaN    20181TBNO        NO        40.0
# 1                  0.0          NaN    20181TBNO        NO        40.0
# 2                  0.0          NaN    20181TBNO        NO        40.0
# 3                  0.0          NaN   20181KCLAC       LAC        28.0
# 4                  0.0          NaN  20181PITCLE       CLE        21.0
#
#    HomeYards  AwayTeam  AwayPoints  AwayYards
# 0      475.0        TB        48.0      529.0
# 1      475.0        TB        48.0      529.0
# 2      475.0        TB        48.0      529.0
# 3      541.0        KC        38.0      362.0
# 4      327.0       PIT        21.0      472.0
#
# [5 rows x 65 columns]

# %%
data.isna().sum()
# Out:
# Unnamed: 0      0
# Unnamed: 0.1    0
# GameKey         0
# PlayerID        0
# Season          0
#                ..
# HomePoints      0
# HomeYards       0
# AwayTeam        0
# AwayPoints      0
# AwayYards       0
# Length: 65, dtype: int64

# %% [markdown]
# Before the train test split, we have to calculate the trailing average fantasy points for each observation, as we cannot incorporate this step into the pipeline without causing data leakage.

# %%
def trailing_stats(df):
    
    """
    Function to create a new column with a trailing aggregate mean
    as a new feature for prediction.
    
    Inputs:
        - df: The dataframe on which the function will be applied
        - Column: The column on which to apply the function
        - Window: The number of past values to consider when apply the function

        
    Output:
        - An aggregate value
        
    """
    #Access the column names in stats_for_trailing
    global stats_for_trailing
    
    # Get all unique players in the DataFrame
    players = df['Name'].unique().tolist()
    
    # Define a DataFrame to hold our values
    df_out = pd.DataFrame()
    # Loop through the unique players
    for player in players:
        # Create a temporary dataframe for each player
        temp_df = df[df['Name'] == player]
        # Calculate the n game trailing average for all players.  Set closed parameter to 'left'
        # so that the current value for fantasy points is not included in the calculation.
        # Backfill the two resulting NaN values
        for column in stats_for_trailing:
            temp_df[f'TA{column}'] = temp_df.loc[:,column].rolling(window = 5, 
                                                              closed = 'left').mean().fillna(method = 'bfill')
        # Append the temporary dataframe to the output
        df_out = df_out.append(temp_df)
    # Return a dataframe with the values sorted by the original index
    return df_out.sort_index()

# %%
stats_for_trailing = ['FantasyPointsPPR']

# %%
# Prepare the trailing average fantasy points column

data = trailing_stats(data)
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1    GameKey  PlayerID  Season             GameDate  \
# 0           0             0  201810122      8283    2018  2018-09-09T13:00:00
# 1           1             1  201810122     18878    2018  2018-09-09T13:00:00
# 2           2             2  201810122      7242    2018  2018-09-09T13:00:00
# 3           4             4  201810129     18082    2018  2018-09-09T16:05:00
# 4           5             5  201810108     18983    2018  2018-09-09T13:00:00
#
#    Week Team Opponent HomeOrAway  ...  FieldGoalsMade50Plus InjuryStatus  \
# 0     1   TB       NO       AWAY  ...                   0.0          NaN
# 1     1   NO       TB       HOME  ...                   0.0          NaN
# 2     1   NO       TB       HOME  ...                   0.0          NaN
# 3     1   KC      LAC       AWAY  ...                   0.0          NaN
# 4     1  PIT      CLE       AWAY  ...                   0.0          NaN
#
#    MatchString  HomeTeam  HomePoints  HomeYards  AwayTeam  AwayPoints  \
# 0    20181TBNO        NO        40.0      475.0        TB        48.0
# 1    20181TBNO        NO        40.0      475.0        TB        48.0
# 2    20181TBNO        NO        40.0      475.0        TB        48.0
# 3   20181KCLAC       LAC        28.0      541.0        KC        38.0
# 4  20181PITCLE       CLE        21.0      327.0       PIT        21.0
#
#    AwayYards  TAFantasyPointsPPR
# 0      529.0              20.088
# 1      529.0              28.600
# 2      529.0              25.204
# 3      362.0              18.240
# 4      472.0              22.420
#
# [5 rows x 66 columns]

# %% [markdown]
# ### Train Test Split

# %%
# Separate data from the target
y = data['FantasyPointsPPR']
data.drop(columns = ['FantasyPointsPPR'],
            inplace = True)
X = data

# %%
# Execute the train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                   test_size = 0.25,
                                                   random_state = 13)

# %% [markdown]
# ### Feature Engineering
#
# The main features that we will be engineering to predict a player's fantasy output will be the 5-game trailing average of various statistics as well as the binning of players into their respective tiers based on recent performance.

# %%
# Define the columns for which we want a 5 game trailing average.

stats_for_trailing = ['TotalTouchdowns','RushingYards','PassingInterceptions','PassingTouchdowns','PassingRating','PassingYards',
                      'PassingCompletionPercentage','RushingYards', 'RushingTouchdowns', 'RushingLong',
                      'Receptions','ReceivingYards','ReceivingTargets', 'ReceivingTouchdowns', 'ExtraPointsMade', 'FieldGoalsMade',
                      'Fumbles','FumblesLost']

trailing_stats = []
for col in stats_for_trailing:
    trailing_stats.append('TA' + col)
trailing_stats
# Out:
# ['TATotalTouchdowns',
#  'TARushingYards',
#  'TAPassingInterceptions',
#  'TAPassingTouchdowns',
#  'TAPassingRating',
#  'TAPassingYards',
#  'TAPassingCompletionPercentage',
#  'TARushingYards',
#  'TARushingTouchdowns',
#  'TARushingLong',
#  'TAReceptions',
#  'TAReceivingYards',
#  'TAReceivingTargets',
#  'TAReceivingTouchdowns',
#  'TAExtraPointsMade',
#  'TAFieldGoalsMade',
#  'TAFumbles',
#  'TAFumblesLost']

# %%
# Instantiate the function transformers for the feature engineering pipeline

touchdown_transformer = FunctionTransformer(get_touchdowns) # Get total touchdowns per player
trailing_transformer = FunctionTransformer(trailing_stats_mean) # Get the 5 game trailing averages of appropriate statistics
tier_transformer = FunctionTransformer(get_tiers) # Bin players into the appropriate tiers based on recent performance


# Instantiate the pipeline for the necessary transformations

engineering = Pipeline([('touchdown', touchdown_transformer),
                       ('trailing', trailing_transformer),
                       ('tier', tier_transformer)])

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23653 entries, 0 to 31537
# Data columns (total 84 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     23653 non-null  int64
#  1   Unnamed: 0.1                   23653 non-null  int64
#  2   GameKey                        23653 non-null  int64
#  3   PlayerID                       23653 non-null  int64
#  4   Season                         23653 non-null  int64
#  5   GameDate                       23653 non-null  object
#  6   Week                           23653 non-null  int64
#  7   Team                           23653 non-null  object
#  8   Opponent                       23653 non-null  object
#  9   HomeOrAway                     23653 non-null  object
#  10  Number                         23653 non-null  int64
#  11  Name                           23653 non-null  object
#  12  Position                       23653 non-null  object
#  13  Started                        23653 non-null  int64
#  14  PassingAttempts                23653 non-null  float64
#  15  PassingCompletions             23653 non-null  float64
#  16  PassingYards                   23653 non-null  float64
#  17  PassingCompletionPercentage    23653 non-null  float64
#  18  PassingYardsPerAttempt         23653 non-null  float64
#  19  PassingYardsPerCompletion      23653 non-null  float64
#  20  PassingTouchdowns              23653 non-null  float64
#  21  PassingInterceptions           23653 non-null  float64
#  22  PassingRating                  23653 non-null  float64
#  23  PassingLong                    23653 non-null  float64
#  24  PassingSacks                   23653 non-null  float64
#  25  PassingSackYards               23653 non-null  float64
#  26  RushingAttempts                23653 non-null  float64
#  27  RushingYards                   23653 non-null  float64
#  28  RushingYardsPerAttempt         23653 non-null  float64
#  29  RushingTouchdowns              23653 non-null  float64
#  30  RushingLong                    23653 non-null  float64
#  31  ReceivingTargets               23653 non-null  float64
#  32  Receptions                     23653 non-null  float64
#  33  ReceivingYards                 23653 non-null  float64
#  34  ReceivingYardsPerReception     23653 non-null  float64
#  35  ReceivingTouchdowns            23653 non-null  float64
#  36  ReceivingLong                  23653 non-null  float64
#  37  Fumbles                        23653 non-null  float64
#  38  FumblesLost                    23653 non-null  float64
#  39  PuntReturns                    23653 non-null  float64
#  40  PuntReturnYards                23653 non-null  float64
#  41  PuntReturnTouchdowns           23653 non-null  float64
#  42  KickReturns                    23653 non-null  float64
#  43  KickReturnYards                23653 non-null  float64
#  44  KickReturnTouchdowns           23653 non-null  float64
#  45  FieldGoalsAttempted            23653 non-null  float64
#  46  FieldGoalsMade                 23653 non-null  float64
#  47  ExtraPointsMade                23653 non-null  float64
#  48  TwoPointConversionPasses       23653 non-null  float64
#  49  TwoPointConversionRuns         23653 non-null  float64
#  50  TwoPointConversionReceptions   23653 non-null  float64
#  51  FieldGoalsMade0to19            23653 non-null  float64
#  52  FieldGoalsMade20to29           23653 non-null  float64
#  53  FieldGoalsMade30to39           23653 non-null  float64
#  54  FieldGoalsMade40to49           23653 non-null  float64
#  55  FieldGoalsMade50Plus           23653 non-null  float64
#  56  InjuryStatus                   2572 non-null   object
#  57  MatchString                    23653 non-null  object
#  58  HomeTeam                       23653 non-null  object
#  59  HomePoints                     23653 non-null  float64
#  60  HomeYards                      23653 non-null  float64
#  61  AwayTeam                       23653 non-null  object
#  62  AwayPoints                     23653 non-null  float64
#  63  AwayYards                      23653 non-null  float64
#  64  TAFantasyPointsPPR             23300 non-null  float64
#  65  TotalTouchdowns                23653 non-null  float64
#  66  TATotalTouchdowns              23065 non-null  float64
#  67  TARushingYards                 23065 non-null  float64
#  68  TAPassingInterceptions         23065 non-null  float64
#  69  TAPassingTouchdowns            23065 non-null  float64
#  70  TAPassingRating                23065 non-null  float64
#  71  TAPassingYards                 23065 non-null  float64
#  72  TAPassingCompletionPercentage  23065 non-null  float64
#  73  TARushingTouchdowns            23065 non-null  float64
#  74  TARushingLong                  23065 non-null  float64
#  75  TAReceptions                   23065 non-null  float64
#  76  TAReceivingYards               23065 non-null  float64
#  77  TAReceivingTargets             23065 non-null  float64
#  78  TAReceivingTouchdowns          23065 non-null  float64
#  79  TAExtraPointsMade              23065 non-null  float64
#  80  TAFieldGoalsMade               23065 non-null  float64
#  81  TAFumbles                      23065 non-null  float64
#  82  TAFumblesLost                  23065 non-null  float64
#  83  PlayerTier                     23653 non-null  object
# dtypes: float64(65), int64(8), object(11)
# memory usage: 15.3+ MB

# %% [markdown]
# <br>
#
# ### Preprocessing
#
# As shown above, the bulk of the null values fall into one of two categories.  They are either:
# * In the InjuryStatus column
#     * Here we can impute a value of healthy, as the only values in the injury column are
# * In the TA (trailing average) columns we created
#     * No player with a null value played more than 5 games, therefore we cannot calculate the trailing average for them.  We will impute a default value of 0 for these columns, as they represent players who likely did not have much impact.  If they had an impact, they likely would have played in more games.  I will explore imputing the median value as well through a grid search.

# %%
# Define the groups of columns for preprocessing steps.

categorical_columns = ['Week',
                       'Team',
                      'Opponent',
                      'PlayerTier',
                      'InjuryStatus']
numerical_columns = trailing_stats

# %%
# Define the preprocessing steps for categorical features
categorical_transform = Pipeline([('impute_cat',SimpleImputer(strategy = 'constant',
                                                              fill_value = 'Healthy')),
                                 ('one_hot_encoder', OneHotEncoder())])

# Define the preprocessing steps for numerical features
numerical_transform = Pipeline([('impute_num', SimpleImputer(strategy = 'constant',
                                                             fill_value = 0)),
                               ('scaler', StandardScaler())])

# Instantiate the column transformer object for the preprocessing steps
preprocessing = ColumnTransformer([('num', numerical_transform, numerical_columns),
                                  ('cat', categorical_transform, categorical_columns)])

# %%
# Instantiate a pipeline with a linear regression model as a baseline

pipeline = Pipeline([('engineering', engineering),
                    ('prep', preprocessing),
                    ('model', RandomForestRegressor())])

# %%
# Set param grid values, parameters for grid search 

param_grid = {'model__n_estimators': [50, 75, 100],
             'model__max_depth': [4, 5, 6]}

grid_search = GridSearchCV(pipeline, 
                          param_grid = param_grid,
                          cv = 3)

# %%
# Fit the grid search to X_train and y_train

grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('engineering',
#                                         Pipeline(steps=[('touchdown',
#                                                          FunctionTransformer(func=<function get_touchdowns at 0x7fd594919a60>)),
#                                                         ('trailing',
#                                                          FunctionTransformer(func=<function trailing_stats_mean at 0x7fd594919550>)),
#                                                         ('tier',
#                                                          FunctionTransformer(func=<function get_tiers at 0x7fd5949199d0>))])),
#                                        ('prep',
#                                         ColumnTransformer(transform...
#                                                                           'TAFieldGoalsMade',
#                                                                           'TAFumbles',
#                                                                           'TAFumblesLost']),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('impute_cat',
#                                                                                           SimpleImputer(fill_value='Healthy',
#                                                                                                         strategy='constant')),
#                                                                                          ('one_hot_encoder',
#                                                                                           OneHotEncoder())]),
#                                                                          ['Week',
#                                                                           'Team',
#                                                                           'Opponent',
#                                                                           'PlayerTier',
#                                                                           'InjuryStatus'])])),
#                                        ('model', RandomForestRegressor())]),
#              param_grid={'model__max_depth': [4, 5, 6],
#                          'model__n_estimators': [50, 75, 100]})

# %%
grid_search.best_score_
# Out:
# -0.0009927446825482484

# %%
preds = grid_search.predict(X_test)

# %%
mean_squared_error(y_test, preds)
# Out:
# 58.31851714240684

# %%
mean_absolute_error(y_test, preds)
# Out:
# 5.957462236316819

# %% [markdown]
# Let's dig into the predictions a little bit

# %%
y_test
# Out:
# 22597     9.0
# 30981     0.0
# 14444    19.5
# 20883     0.0
# 21136     9.8
#          ...
# 7713      0.0
# 9304      0.0
# 22562    16.0
# 21120     6.8
# 28390     2.3
# Name: FantasyPointsPPR, Length: 7885, dtype: float64

# %%
df_preds = pd.DataFrame(y_test)

# %%
df_preds['Predicted'] = preds

# %%
df_preds[:50].sort_values(by = 'Predicted', ascending = False)
# Out:
#        FantasyPointsPPR  Predicted
# 11479              0.00   7.702086
# 14236              0.00   6.089954
# 24398              2.80   5.844874
# 19997             24.74   5.818603
# 13250              0.00   5.812071
# 15286              0.70   5.785077
# 14276              0.00   5.783938
# 3195              16.00   5.766087
# 30987              0.00   5.708916
# 1410               0.00   5.698768
# 13319              0.00   5.641062
# 30981              0.00   5.611946
# 17994              6.30   5.600487
# 21045             12.54   5.591262
# 9700               2.70   5.590364
# 24004              0.00   5.590360
# 15136              7.80   5.585143
# 25101              0.00   5.583796
# 22234              3.40   5.581735
# 30595             30.64   5.581015
# 21786              0.10   5.575742
# 10218              4.70   5.575137
# 14870              0.00   5.574056
# 27770              8.80   5.570975
# 21123             10.60   5.570975
# 26715             10.60   5.566213
# 18654              1.90   5.562496
# 12333              0.00   5.561446
# 14444             19.50   5.560689
# 7187              25.00   5.560637
# 30488              0.00   5.560205
# 22574             11.10   5.557957
# 9584               8.40   5.549928
# 20612              8.60   5.546290
# 24710              0.00   5.544842
# 1532              10.70   5.535579
# 4384               0.00   5.532030
# 22177              7.30   5.527099
# 12732              2.60   5.527018
# 11389              0.00   5.396729
# 13912              0.00   5.332500
# 10939              0.00   5.319395
# 11021             -1.20   5.275742
# 21148              4.00   5.272397
# 1361               0.00   5.256001
# 881                0.00   5.243375
# 19470              0.00   5.053344
# 22597              9.00   5.036571
# 21136              9.80   4.816337
# 20883              0.00   4.768551
