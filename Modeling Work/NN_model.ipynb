# %% [markdown]
# ### Import packages
#
# Import of the packages that will be needed for the project.  This includes packages for data manipulation, sklearn modules and custom functions.

# %%
import pandas as pd
import numpy as np
import pickle

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.compose import ColumnTransformer
from sklearn.base import TransformerMixin
from sklearn.preprocessing import OneHotEncoder, RobustScaler, StandardScaler, FunctionTransformer, PowerTransformer

from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.wrappers.scikit_learn import KerasRegressor

# %%
import warnings
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action = 'ignore')

# %%
pip install pandas==1.2.0
# Out:
# Requirement already satisfied: pandas==1.2.0 in /usr/local/lib/python3.7/dist-packages (1.2.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.2.0) (2.8.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from pandas==1.2.0) (1.19.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.2.0) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas==1.2.0) (1.15.0)

# %% [markdown]
# ### Import Data
#
# Let's import the dataframe that we will be using for modelling

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv('drive/MyDrive/LHL_Final_Project/Data/weekly_data.csv')
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1    GameKey  ...  OpponentPoints YardsFor YardsAgainst
# 0           0             0  201810122  ...              40      529          475
# 1           1             1  201810122  ...              48      475          529
# 2           2             2  201810122  ...              48      475          529
# 3           3             4  201810129  ...              28      362          541
# 4           4             5  201810108  ...              21      472          327
#
# [5 rows x 63 columns]

# %%
data['Week'] = data['Week'].astype(str)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32046 entries, 0 to 32045
# Data columns (total 63 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    32046 non-null  int64
#  1   Unnamed: 0.1                  32046 non-null  int64
#  2   GameKey                       32046 non-null  int64
#  3   PlayerID                      32046 non-null  int64
#  4   GameDate                      32046 non-null  object
#  5   Team                          32046 non-null  object
#  6   Opponent                      32046 non-null  object
#  7   HomeOrAway                    32046 non-null  object
#  8   Number                        32046 non-null  int64
#  9   Name                          32046 non-null  object
#  10  Position                      32046 non-null  object
#  11  Started                       32046 non-null  int64
#  12  PassingAttempts               32046 non-null  float64
#  13  PassingCompletions            32046 non-null  float64
#  14  PassingYards                  32046 non-null  float64
#  15  PassingCompletionPercentage   32046 non-null  float64
#  16  PassingYardsPerAttempt        32046 non-null  float64
#  17  PassingYardsPerCompletion     32046 non-null  float64
#  18  PassingTouchdowns             32046 non-null  float64
#  19  PassingInterceptions          32046 non-null  float64
#  20  PassingRating                 32046 non-null  float64
#  21  PassingLong                   32046 non-null  float64
#  22  PassingSacks                  32046 non-null  float64
#  23  PassingSackYards              32046 non-null  float64
#  24  RushingAttempts               32046 non-null  float64
#  25  RushingYards                  32046 non-null  float64
#  26  RushingYardsPerAttempt        32046 non-null  float64
#  27  RushingTouchdowns             32046 non-null  float64
#  28  RushingLong                   32046 non-null  float64
#  29  ReceivingTargets              32046 non-null  float64
#  30  Receptions                    32046 non-null  float64
#  31  ReceivingYards                32046 non-null  float64
#  32  ReceivingYardsPerReception    32046 non-null  float64
#  33  ReceivingTouchdowns           32046 non-null  float64
#  34  ReceivingLong                 32046 non-null  float64
#  35  Fumbles                       32046 non-null  float64
#  36  FumblesLost                   32046 non-null  float64
#  37  PuntReturns                   32046 non-null  float64
#  38  PuntReturnYards               32046 non-null  float64
#  39  PuntReturnTouchdowns          32046 non-null  float64
#  40  KickReturns                   32046 non-null  float64
#  41  KickReturnYards               32046 non-null  float64
#  42  KickReturnTouchdowns          32046 non-null  float64
#  43  FieldGoalsAttempted           32046 non-null  float64
#  44  FieldGoalsMade                32046 non-null  float64
#  45  ExtraPointsMade               32046 non-null  float64
#  46  TwoPointConversionPasses      32046 non-null  float64
#  47  TwoPointConversionRuns        32046 non-null  float64
#  48  TwoPointConversionReceptions  32046 non-null  float64
#  49  FantasyPointsPPR              32046 non-null  float64
#  50  FieldGoalsMade0to19           32046 non-null  float64
#  51  FieldGoalsMade20to29          32046 non-null  float64
#  52  FieldGoalsMade30to39          32046 non-null  float64
#  53  FieldGoalsMade40to49          32046 non-null  float64
#  54  FieldGoalsMade50Plus          32046 non-null  float64
#  55  InjuryStatus                  3460 non-null   object
#  56  MatchString                   32046 non-null  object
#  57  Season                        32046 non-null  int64
#  58  Week                          32046 non-null  object
#  59  TeamPoints                    32046 non-null  int64
#  60  OpponentPoints                32046 non-null  int64
#  61  YardsFor                      32046 non-null  int64
#  62  YardsAgainst                  32046 non-null  int64
# dtypes: float64(43), int64(11), object(9)
# memory usage: 15.4+ MB

# %%
# Get a list of unique player names in the dataset for use in the one hot
# encoder in our data prep pipeline

unique_players = data['Name'].unique().tolist()
len(unique_players)
# Out:
# 1247

# %% [markdown]
# Before the train test split, we have to calculate the trailing average fantasy points for each observation, as we cannot incorporate this step into the pipeline without causing data leakage.

# %%
import pandas as pd
import numpy as np

def offensive_contribution(team_yards, player_yards):
    
    """
    Calculate a percentage for the percentage of team yards that a player contributes to.
    
    Input:  
        - Dataframe to use in the calculation
        
    Output:
        - New dataframe column with the desired contribution score
    """
    contribution = player_yards / team_yards
    if contribution > 1.0:
        return 1.0
    else:
        return contribution     

  #--------------------------------------------------------------------      
      
def get_contribution(df):
    
    """
    Apply offensive_contribution(), taking in the whole dataframe as input.
    """
    
    df['YardageContribution'] = df.apply(lambda x: offensive_contribution(x['YardsFor'],
                                                                         x['TotalYards'],
                                                                         ), axis = 1)
                                                      
    return df

#---------------------------------------------------------
# Define the stats for which we need to calculate trailing averages
stats_for_trailing = ['TotalTouchdowns','RushingYards','PassingInterceptions','PassingTouchdowns','PassingRating','PassingYards',
                      'PassingCompletionPercentage', 'PassingLong','RushingYards', 'RushingTouchdowns', 'RushingLong',
                      'RushingYardsPerAttempt', 'ReceivingYardsPerReception', 'PuntReturns', 'PuntReturnTouchdowns',
                      'Receptions','ReceivingYards','ReceivingTargets', 'ReceivingTouchdowns', 'ExtraPointsMade', 'FieldGoalsMade',
                      'FieldGoalsMade40to49','FieldGoalsMade50Plus','Fumbles','FumblesLost', 'TeamPoints', 'OpponentPoints', 'YardsFor', 'YardsAgainst']


def trailing_stats_mean(df):
    
    """
    Function to create a dataframe with a trailing aggregate mean
    as a new feature for prediction.  Does so for each column in the global
    variable stats_for_trailing
    
    Inputs:
        - df: The dataframe on which the function will be applied
        - Column: The column on which to apply the function
        - Window: The number of past values to consider when apply the function

        
    Output:
        - An aggregate value
        
    """
    #Access the column names in stats_for_trailing
    global stats_for_trailing
    
    # Get all unique players in the DataFrame
    players = df['Name'].unique().tolist()
    
    # Define a DataFrame to hold our values
    df_out = pd.DataFrame()
    # Loop through the unique players
    for player in players:
        # Create a temporary dataframe for each player
        temp_df = df[df['Name'] == player]
        # Calculate the n game trailing average for all players.  Set closed parameter to 'left'
        # so that the current value for fantasy points is not included in the calculation.
        # Backfill the two resulting NaN values
        for column in stats_for_trailing:
            temp_df[f'TA7{column}'] = temp_df[column].fillna(method = 'ffill').rolling(window = 7, 
                                                              closed = 'left').mean().fillna(method = 'bfill')
            temp_df[f'TA3{column}'] = temp_df[column].rolling(window = 3, 
                                                              closed = 'left').mean().fillna(method = 'bfill') 
        # Append the temporary dataframe to the output
        df_out = df_out.append(temp_df)
    # Return a dataframe with the values sorted by the original index
    df_out.sort_index(inplace = True)
    return df_out
    
#---------------------------------------------------------

def trailing_stats_single_column(df, column):
    
    """
    Function to create a new column with a trailing aggregate mean
    as a new feature for prediction.
    
    Inputs:
        - df: The dataframe on which the function will be applied
        - Column: The column on which to apply the function
        - Window: The number of past values to consider when apply the function

        
    Output:
        - An aggregate value
        
    """
    
    # Get all unique players in the DataFrame
    players = df['Name'].unique().tolist()
    
    # Make a dataframe to store the output
    df_out = pd.DataFrame()
    # Loop through the unique players
    for player in players:
        # Create a temporary dataframe for each player
        temp_df = df[df['Name'] == player]
        # Calculate the n game trailing average for all players.  Set closed parameter to 'left'
        # so that the current value for fantasy points is not included in the calculation.
        # Backfill the two resulting NaN values
       
        temp_df[f'TA7{column}'] = temp_df[column].fillna(method='ffill').rolling(window = 7, 
                                                            closed = 'left').mean().fillna(method = 'bfill')
        temp_df[f'TA3{column}'] = temp_df[column].rolling(window = 3, 
                                                              closed = 'left').mean().fillna(method = 'bfill')                                                     
        # Append the temporary dataframe to the output
        df_out = df_out.append(temp_df)
    # Return a dataframe with the values sorted by the original index
    df_out.sort_index(inplace = True)
    return df_out
    
#---------------------------------------------------------

def tier_maker(position, points):
    
    """
    Take in two arguments:
    
     - Position: Column of the dataframe holding the player position
     - Points: Trailing average of fantasy points for a given player
    
    Classify players at every position to a tier based on their recent 
    performance (Trailing average fantasy points). Classifications will work
    as follows.
    
    Running Back:
        -RB1: Trailing average greater than 18pts
        -RB2: Trailing average between 12 and 18 pts
        -RB3: Trailing average between 8 and 12 pts
        -RB4: Trailing average below 8 pts
        
    Wide Receiver:
        -WR1: Trailing average greater than 18pts
        -WR2: Trailing average between 12 and 18 pts
        -WR3: Trailing average between 8 and 12 pts
        -WR4: Trailing average below 8 pts
        
    Tight End:
        -TE1: Trailing average greater than 15pts
        -TE2: Trailing average between 10 and 15 pts
        -TE3: Trailing average below 10 pts
        
    Quarterback:
        -QB1: Trailing average greater than 24pts
        -QB2: Trailing average between 18 and 24pts
        -QB3: Trailing average between 12 and 18pts
        -QB4: Trailing average below 12 pts
    
    Kicker:
        - K1: Trailing average greater than 10 pts
        - K2: Trailing average between 7 and 10 points
        - K3: Trailing average below 7 points
        """

    # Let's make tier assignments for running backs
    if position == 'RB':
        if points > 18:
            return 'RB1'
        elif 12 < points <= 18:
            return 'RB2'
        elif 8 < points <= 12:
            return 'RB3'
        else:
            return 'RB4'
            
    # Let's make tier assignments for wide receivers
    if position == 'WR':
        if points > 18:
            return 'WR1'
        elif 12 < points <= 18:
            return 'WR2'
        elif 8 < points <= 12:
            return 'WR3'
        else:
            return 'WR4'
            
    # Let's make tier assignments for tight ends
    if position == 'TE':
        if points > 15:
            return 'TE1'
        elif 10 < points <= 15:
            return 'TE2'
        else:
            return 'TE3'
    
    # Let's make tier assignments for quarterbacks
    if position == 'QB':
        if points > 24:
            return 'QB1'
        elif 16 < points <= 22:
            return 'QB2'
        elif 10 < points <= 16:
            return 'QB3'
        else:
            return 'QB4'

    # Let's make tier assignments for kickers
    if position == 'K':
        if points > 10:
            return 'K1'
        elif 7 < points <= 10:
            return 'K2'
        else:
            return 'K3'
    
    # If noting is returned before this point, return np.nan
    return np.nan
#---------------------------------------------------------------------

def get_tiers(df):
    
    """
    Apply the tier_maker function to the entire dataframe.
    """
    
    df['PlayerTier'] = df.apply(lambda x: tier_maker(x['Position'], x['TA7FantasyPointsPPR']),
                               axis = 1)
    return df
#---------------------------------------------------------------------

def get_touchdowns(df):
    
    """
    Get the total number of touchdowns for a player in a given week.
    
    Input:
        - Dataframe
    Output:
        - Dataframe with a new column representing total touchdowns"""
    
    TD_sum = df['ReceivingTouchdowns'] + df['RushingTouchdowns'] + df['PassingTouchdowns']
    df['TotalTouchdowns'] = TD_sum
    
    return df

def get_yards(df):
    
    """
    Get the total number of yards for a player in a given week.
    
    Input:
        - Dataframe
    Output:
        - Dataframe with a new column representing total touchdowns"""
    
    yardage_sum = df['ReceivingYards'] + df['RushingYards'] + df['PassingYards']
    df['TotalYards'] = yardage_sum
    
    return df

#---------------------------------------------------------------------

def LogShift(X):
    
    X_10 = X + 10
    X_log = np.log(X_10)
    
    return X_log

#---------------------------------------------------------------------
from sklearn.base import TransformerMixin
# Build a new transformer class to convert the sparse matrix output of the 
# pipeline to a dense matrix compatible with the model

class DenseTransformer(TransformerMixin):

    def fit(self, X, y = None, **fit_params):
        return self

    def transform(self, X, y = None, **fit_params):
        return X.todense()

# %%
stats_for_trailing = ['FantasyPointsPPR']
data = trailing_stats_mean(data)

# %% [markdown]
# ### Train Test Split

# %%
# Separate data from the target
y = data['FantasyPointsPPR']
data.drop(columns = ['FantasyPointsPPR'],
            inplace = True)
X = data

# %%
# Execute the train, test split
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                   test_size = 0.3,
                                                   random_state = 13,
                                                    shuffle = False)

# %% [markdown]
# ### Feature Engineering
#
# The main features that we will be engineering to predict a player's fantasy output will be the 5-game trailing average of various statistics as well as the binning of players into their respective tiers based on recent performance.

# %%
# Define the columns for which we want a 5 game trailing average.

stats_for_trailing = ['TotalTouchdowns','RushingYards','PassingInterceptions','PassingTouchdowns','PassingRating','PassingYards',
                      'PassingCompletionPercentage', 'PassingLong','RushingYards', 'RushingTouchdowns', 'RushingLong',
                      'RushingYardsPerAttempt', 'ReceivingYardsPerReception', 'PuntReturns', 'PuntReturnTouchdowns',
                      'Receptions','ReceivingYards','ReceivingTargets', 'ReceivingTouchdowns', 'ExtraPointsMade', 'FieldGoalsMade',
                      'FieldGoalsMade40to49','FieldGoalsMade50Plus','Fumbles','FumblesLost', 'TeamPoints', 'OpponentPoints',
                     'YardsFor', 'YardsAgainst']

trailing_stats = []
for col in stats_for_trailing:
    trailing_stats.append('TA3' + col)
    trailing_stats.append('TA7' + col)
trailing_stats.append('TA3FantasyPointsPPR')
trailing_stats.append('TA7FantasyPointsPPR')

# %%
# Instantiate the function transformers for the feature engineering pipeline

touchdown_transformer = FunctionTransformer(get_touchdowns) # Get total touchdowns per week per player
yard_transformer = FunctionTransformer(get_yards) # Get total yardage per week per player
trailing_transformer = FunctionTransformer(trailing_stats_mean) # Get the 5 game trailing averages of appropriate statistics
tier_transformer = FunctionTransformer(get_tiers) # Bin players into the appropriate tiers based on recent performance
contribution_transformer = FunctionTransformer(get_contribution) # Calculate the offensive contribution of a given player relative to the team's offense


# Instantiate the pipeline for the necessary transformations

engineering = Pipeline([('touchdown', touchdown_transformer),
                        ('yards', yard_transformer),
                       ('trailing', trailing_transformer),
                       ('tier', tier_transformer),
                       ('contribution', contribution_transformer)])

# %%
# Build a new transformer class to convert the sparse matrix output of the 
# pipeline to a dense matrix compatible with the NN

class DenseTransformer(TransformerMixin):

    def fit(self, X, y = None, **fit_params):
        return self

    def transform(self, X, y = None, **fit_params):
        return X.todense()

# %%
# Create an instance of the logshift transformer

LogShiftTransformer = FunctionTransformer(LogShift)

# %% [markdown]
# <br>
#
# ### Preprocessing
#
# As shown above, the bulk of the null values fall into one of two categories.  They are either:
# * In the InjuryStatus column
#     * Here we can impute a value of healthy, as the only values in the injury column are
# * In the TA (trailing average) columns we created
#     * No player with a null value played more than 5 games, therefore we cannot calculate the trailing average for them.  We will impute a default value of 0 for these columns, as they represent players who likely did not have much impact.  If they had an impact, they likely would have played in more games.  I will explore imputing the median value as well through a grid search.

# %%
# Define the groups of columns for preprocessing steps.

categorical_columns = ['Week',
                    #    'Name',
                       'Team',
                       'Opponent',
                       'PlayerTier']
numerical_columns = trailing_stats

# %%
# Define the preprocessing steps for categorical features
categorical_transform = Pipeline([('impute_cat',SimpleImputer(strategy = 'most_frequent')),
                                 ('one_hot_encoder', OneHotEncoder(handle_unknown = 'ignore'))])

# Define the preprocessing steps for numerical features
numerical_transform = Pipeline([('impute_num', SimpleImputer(strategy = 'constant', fill_value = 0)), 
                                ('scaler', RobustScaler())])

# Instantiate the column transformer object for the preprocessing steps
preprocessing = ColumnTransformer([('num', numerical_transform, numerical_columns),
                                  ('cat', categorical_transform, categorical_columns)])

# %%
eng_prep_pipe = Pipeline([('engineering', engineering),
                          ('prep', preprocessing)])

df_train = eng_prep_pipe.fit_transform(X_train)
df_test = eng_prep_pipe.fit_transform(X_test)

# %%
# df_test  = df_test.todense()
# df_train = df_train.todense()

# %%
def create_model(optimizer = 'Adam'):

    model = Sequential()
    model.add(Dense(128, input_dim = df_train.shape[1], activation = 'tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(512, activation = 'tanh'))
    # model.add(Dense(1024, activation = 'tanh'))
    model.add(Dropout(0.5))
    model.add(Dense(64, activation = 'tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(32, activation = 'tanh'))
    model.add(Dense(8, activation = 'relu'))
    model.add(Dense(1))
    model.compile(loss = 'mean_squared_error', optimizer = optimizer)
    print(model.summary())
    return model

# %%
# Instantiate a pipeline with a linear regression model as a baseline

model = KerasRegressor(build_fn = create_model,
                                             epochs = 1000,
                                             batch_size = 256,
                                             verbose = 2)

# %%
pipeline = Pipeline([('engineering', engineering),
                     ('prep', preprocessing),
                     ('todense', DenseTransformer()),
                      ('network', model)])

# %%
# Set param grid values, parameters for grid search 

param_grid = {}

grid_search = GridSearchCV(model, 
                          param_grid = param_grid,
                          cv = 3,
                          verbose = 2,
                          n_jobs = -2)

# %%
history = model.fit(df_train, y_train,
                    validation_data = (df_test, y_test))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               20480
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 512)               66048
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 64)                32832
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 8)                 264
#
#  dense_5 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 121,713
# Trainable params: 121,713
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/1000
# 88/88 - 2s - loss: 51.1773 - val_loss: 37.2497 - 2s/epoch - 17ms/step
# Epoch 2/1000
# 88/88 - 1s - loss: 36.1843 - val_loss: 33.9697 - 741ms/epoch - 8ms/step
# Epoch 3/1000
# 88/88 - 1s - loss: 34.2380 - val_loss: 33.0385 - 755ms/epoch - 9ms/step
# Epoch 4/1000
# 88/88 - 1s - loss: 33.8626 - val_loss: 32.3344 - 751ms/epoch - 9ms/step
# Epoch 5/1000
# 88/88 - 1s - loss: 33.3198 - val_loss: 32.6051 - 733ms/epoch - 8ms/step
# Epoch 6/1000
# 88/88 - 1s - loss: 33.0502 - val_loss: 32.5453 - 793ms/epoch - 9ms/step
# Epoch 7/1000
# 88/88 - 1s - loss: 32.9458 - val_loss: 32.6141 - 814ms/epoch - 9ms/step
# Epoch 8/1000
# 88/88 - 1s - loss: 32.7283 - val_loss: 32.8986 - 779ms/epoch - 9ms/step
# Epoch 9/1000
# 88/88 - 1s - loss: 32.8350 - val_loss: 31.9483 - 745ms/epoch - 8ms/step
# Epoch 10/1000
# 88/88 - 1s - loss: 32.5773 - val_loss: 32.8834 - 704ms/epoch - 8ms/step
# Epoch 11/1000
# 88/88 - 1s - loss: 32.1819 - val_loss: 31.9013 - 709ms/epoch - 8ms/step
# Epoch 12/1000
# 88/88 - 1s - loss: 32.2122 - val_loss: 32.0975 - 699ms/epoch - 8ms/step
# Epoch 13/1000
# 88/88 - 1s - loss: 32.1682 - val_loss: 32.4756 - 709ms/epoch - 8ms/step
# Epoch 14/1000
# 88/88 - 1s - loss: 32.1477 - val_loss: 32.4104 - 715ms/epoch - 8ms/step
# Epoch 15/1000
# 88/88 - 1s - loss: 31.9314 - val_loss: 32.5486 - 769ms/epoch - 9ms/step
# Epoch 16/1000
# 88/88 - 1s - loss: 31.8335 - val_loss: 31.7232 - 724ms/epoch - 8ms/step
# Epoch 17/1000
# 88/88 - 1s - loss: 31.6390 - val_loss: 32.9073 - 699ms/epoch - 8ms/step
# Epoch 18/1000
# 88/88 - 1s - loss: 31.7976 - val_loss: 32.5101 - 756ms/epoch - 9ms/step
# Epoch 19/1000
# 88/88 - 1s - loss: 31.6589 - val_loss: 32.4376 - 697ms/epoch - 8ms/step
# Epoch 20/1000
# 88/88 - 1s - loss: 31.8806 - val_loss: 32.1727 - 701ms/epoch - 8ms/step
# Epoch 21/1000
# 88/88 - 1s - loss: 31.6273 - val_loss: 32.6669 - 748ms/epoch - 9ms/step
# Epoch 22/1000
# 88/88 - 1s - loss: 31.7665 - val_loss: 32.9392 - 708ms/epoch - 8ms/step
# Epoch 23/1000
# 88/88 - 1s - loss: 31.6077 - val_loss: 32.1775 - 712ms/epoch - 8ms/step
# Epoch 24/1000
# 88/88 - 1s - loss: 31.5645 - val_loss: 32.1915 - 695ms/epoch - 8ms/step
# Epoch 25/1000
# 88/88 - 1s - loss: 31.7023 - val_loss: 32.1732 - 704ms/epoch - 8ms/step
# Epoch 26/1000
# 88/88 - 1s - loss: 31.5340 - val_loss: 32.3631 - 691ms/epoch - 8ms/step
# Epoch 27/1000
# 88/88 - 1s - loss: 31.3997 - val_loss: 33.1700 - 709ms/epoch - 8ms/step
# Epoch 28/1000
# 88/88 - 1s - loss: 31.2363 - val_loss: 32.6379 - 696ms/epoch - 8ms/step
# Epoch 29/1000
# 88/88 - 1s - loss: 31.3506 - val_loss: 32.4183 - 689ms/epoch - 8ms/step
# Epoch 30/1000
# 88/88 - 1s - loss: 31.3748 - val_loss: 32.7094 - 705ms/epoch - 8ms/step
# Epoch 31/1000
# 88/88 - 1s - loss: 31.2370 - val_loss: 32.6042 - 704ms/epoch - 8ms/step
# Epoch 32/1000
# 88/88 - 1s - loss: 31.1532 - val_loss: 32.0757 - 749ms/epoch - 9ms/step
# Epoch 33/1000
# 88/88 - 1s - loss: 30.9669 - val_loss: 32.1864 - 783ms/epoch - 9ms/step
# Epoch 34/1000
# 88/88 - 1s - loss: 31.1223 - val_loss: 32.8130 - 684ms/epoch - 8ms/step
# Epoch 35/1000
# 88/88 - 1s - loss: 30.9067 - val_loss: 32.3624 - 698ms/epoch - 8ms/step
# Epoch 36/1000
# 88/88 - 1s - loss: 30.8185 - val_loss: 33.0572 - 702ms/epoch - 8ms/step
# Epoch 37/1000
# 88/88 - 1s - loss: 30.8125 - val_loss: 32.1144 - 767ms/epoch - 9ms/step
# Epoch 38/1000
# 88/88 - 1s - loss: 30.6966 - val_loss: 32.4545 - 698ms/epoch - 8ms/step
# Epoch 39/1000
# 88/88 - 1s - loss: 30.7765 - val_loss: 32.2881 - 707ms/epoch - 8ms/step
# Epoch 40/1000
# 88/88 - 1s - loss: 30.8044 - val_loss: 32.2779 - 763ms/epoch - 9ms/step
# Epoch 41/1000
# 88/88 - 1s - loss: 30.6883 - val_loss: 32.4571 - 702ms/epoch - 8ms/step
# Epoch 42/1000
# 88/88 - 1s - loss: 30.6244 - val_loss: 31.9077 - 703ms/epoch - 8ms/step
# Epoch 43/1000
# 88/88 - 1s - loss: 30.5784 - val_loss: 32.5693 - 708ms/epoch - 8ms/step
# Epoch 44/1000
# 88/88 - 1s - loss: 30.4227 - val_loss: 32.4540 - 756ms/epoch - 9ms/step
# Epoch 45/1000
# 88/88 - 1s - loss: 30.5992 - val_loss: 32.7090 - 764ms/epoch - 9ms/step
# Epoch 46/1000
# 88/88 - 1s - loss: 30.3994 - val_loss: 33.0425 - 697ms/epoch - 8ms/step
# Epoch 47/1000
# 88/88 - 1s - loss: 30.5540 - val_loss: 33.1418 - 753ms/epoch - 9ms/step
# Epoch 48/1000
# 88/88 - 1s - loss: 30.3951 - val_loss: 32.2887 - 689ms/epoch - 8ms/step
# Epoch 49/1000
# 88/88 - 1s - loss: 30.4373 - val_loss: 32.3239 - 704ms/epoch - 8ms/step
# Epoch 50/1000
# 88/88 - 1s - loss: 30.0901 - val_loss: 32.7833 - 697ms/epoch - 8ms/step
# Epoch 51/1000
# 88/88 - 1s - loss: 30.2724 - val_loss: 32.2145 - 702ms/epoch - 8ms/step
# Epoch 52/1000
# 88/88 - 1s - loss: 30.0337 - val_loss: 32.6301 - 698ms/epoch - 8ms/step
# Epoch 53/1000
# 88/88 - 1s - loss: 29.9587 - val_loss: 32.7967 - 707ms/epoch - 8ms/step
# Epoch 54/1000
# 88/88 - 1s - loss: 30.1530 - val_loss: 32.6559 - 681ms/epoch - 8ms/step
# Epoch 55/1000
# 88/88 - 1s - loss: 30.0499 - val_loss: 32.6992 - 787ms/epoch - 9ms/step
# Epoch 56/1000
# 88/88 - 1s - loss: 30.1084 - val_loss: 32.5891 - 736ms/epoch - 8ms/step
# Epoch 57/1000
# 88/88 - 1s - loss: 29.9718 - val_loss: 32.8201 - 735ms/epoch - 8ms/step
# Epoch 58/1000
# 88/88 - 1s - loss: 29.9693 - val_loss: 32.9879 - 755ms/epoch - 9ms/step
# Epoch 59/1000
# 88/88 - 1s - loss: 29.7202 - val_loss: 32.8294 - 784ms/epoch - 9ms/step
# Epoch 60/1000
# 88/88 - 1s - loss: 29.8960 - val_loss: 32.5304 - 758ms/epoch - 9ms/step
# Epoch 61/1000
# 88/88 - 1s - loss: 30.0452 - val_loss: 32.6209 - 731ms/epoch - 8ms/step
# Epoch 62/1000
# 88/88 - 1s - loss: 29.7912 - val_loss: 33.0268 - 722ms/epoch - 8ms/step
# Epoch 63/1000
# 88/88 - 1s - loss: 29.9016 - val_loss: 32.8734 - 731ms/epoch - 8ms/step
# Epoch 64/1000
# 88/88 - 1s - loss: 29.8113 - val_loss: 33.0117 - 807ms/epoch - 9ms/step
# Epoch 65/1000
# 88/88 - 1s - loss: 29.7930 - val_loss: 33.2988 - 769ms/epoch - 9ms/step
# Epoch 66/1000
# 88/88 - 1s - loss: 29.7449 - val_loss: 32.9367 - 729ms/epoch - 8ms/step
# Epoch 67/1000
# 88/88 - 1s - loss: 29.4131 - val_loss: 32.9088 - 739ms/epoch - 8ms/step
# Epoch 68/1000
# 88/88 - 1s - loss: 29.4845 - val_loss: 33.1405 - 754ms/epoch - 9ms/step
# Epoch 69/1000
# 88/88 - 1s - loss: 29.4532 - val_loss: 33.4414 - 789ms/epoch - 9ms/step
# Epoch 70/1000
# 88/88 - 1s - loss: 29.5240 - val_loss: 33.4521 - 779ms/epoch - 9ms/step
# Epoch 71/1000
# 88/88 - 1s - loss: 29.4724 - val_loss: 33.2521 - 771ms/epoch - 9ms/step
# Epoch 72/1000
# 88/88 - 1s - loss: 29.3883 - val_loss: 33.3949 - 756ms/epoch - 9ms/step
# Epoch 73/1000
# 88/88 - 1s - loss: 29.1946 - val_loss: 33.2992 - 748ms/epoch - 8ms/step
# Epoch 74/1000
# 88/88 - 1s - loss: 29.1234 - val_loss: 33.7337 - 764ms/epoch - 9ms/step
# Epoch 75/1000
# 88/88 - 1s - loss: 29.3904 - val_loss: 33.0978 - 747ms/epoch - 8ms/step
# Epoch 76/1000
# 88/88 - 1s - loss: 29.1360 - val_loss: 33.4678 - 811ms/epoch - 9ms/step
# Epoch 77/1000
# 88/88 - 1s - loss: 29.4161 - val_loss: 34.0604 - 738ms/epoch - 8ms/step
# Epoch 78/1000
# 88/88 - 1s - loss: 29.0917 - val_loss: 33.0611 - 819ms/epoch - 9ms/step
# Epoch 79/1000
# 88/88 - 1s - loss: 29.2917 - val_loss: 33.2255 - 778ms/epoch - 9ms/step
# Epoch 80/1000
# 88/88 - 1s - loss: 29.2130 - val_loss: 33.6946 - 798ms/epoch - 9ms/step
# Epoch 81/1000
# 88/88 - 1s - loss: 29.1101 - val_loss: 33.3387 - 781ms/epoch - 9ms/step
# Epoch 82/1000
# 88/88 - 1s - loss: 28.8726 - val_loss: 34.4331 - 795ms/epoch - 9ms/step
# Epoch 83/1000
# 88/88 - 1s - loss: 29.0078 - val_loss: 33.2774 - 734ms/epoch - 8ms/step
# Epoch 84/1000
# 88/88 - 1s - loss: 28.7667 - val_loss: 33.6270 - 729ms/epoch - 8ms/step
# Epoch 85/1000
# 88/88 - 1s - loss: 28.8244 - val_loss: 33.2628 - 762ms/epoch - 9ms/step
# Epoch 86/1000
# 88/88 - 1s - loss: 28.9843 - val_loss: 33.4535 - 818ms/epoch - 9ms/step
# Epoch 87/1000
# 88/88 - 1s - loss: 28.6704 - val_loss: 33.3236 - 739ms/epoch - 8ms/step
# Epoch 88/1000
# 88/88 - 1s - loss: 28.7351 - val_loss: 33.5126 - 737ms/epoch - 8ms/step
# Epoch 89/1000
# 88/88 - 1s - loss: 28.6891 - val_loss: 33.4555 - 752ms/epoch - 9ms/step
# Epoch 90/1000
# 88/88 - 1s - loss: 28.8311 - val_loss: 34.0423 - 805ms/epoch - 9ms/step
# Epoch 91/1000
# 88/88 - 1s - loss: 28.8264 - val_loss: 33.6633 - 787ms/epoch - 9ms/step
# Epoch 92/1000
# 88/88 - 1s - loss: 28.5206 - val_loss: 33.7943 - 731ms/epoch - 8ms/step
# Epoch 93/1000
# 88/88 - 1s - loss: 28.6341 - val_loss: 34.0741 - 743ms/epoch - 8ms/step
# Epoch 94/1000
# 88/88 - 1s - loss: 28.7152 - val_loss: 33.3914 - 794ms/epoch - 9ms/step
# Epoch 95/1000
# 88/88 - 1s - loss: 28.5954 - val_loss: 33.6365 - 716ms/epoch - 8ms/step
# Epoch 96/1000
# 88/88 - 1s - loss: 28.5044 - val_loss: 34.1299 - 767ms/epoch - 9ms/step
# Epoch 97/1000
# 88/88 - 1s - loss: 28.5425 - val_loss: 34.0920 - 724ms/epoch - 8ms/step
# Epoch 98/1000
# 88/88 - 1s - loss: 28.5113 - val_loss: 33.8196 - 772ms/epoch - 9ms/step
# Epoch 99/1000
# 88/88 - 1s - loss: 28.1895 - val_loss: 33.8327 - 704ms/epoch - 8ms/step
# Epoch 100/1000
# 88/88 - 1s - loss: 28.2655 - val_loss: 34.2814 - 718ms/epoch - 8ms/step
# Epoch 101/1000
# 88/88 - 1s - loss: 28.1508 - val_loss: 34.2441 - 773ms/epoch - 9ms/step
# Epoch 102/1000
# 88/88 - 1s - loss: 28.2156 - val_loss: 34.1334 - 742ms/epoch - 8ms/step
# Epoch 103/1000
# 88/88 - 1s - loss: 28.1737 - val_loss: 33.7181 - 834ms/epoch - 9ms/step
# Epoch 104/1000
# 88/88 - 1s - loss: 28.0367 - val_loss: 33.8764 - 746ms/epoch - 8ms/step
# Epoch 105/1000
# 88/88 - 1s - loss: 28.1687 - val_loss: 33.8935 - 793ms/epoch - 9ms/step
# Epoch 106/1000
# 88/88 - 1s - loss: 28.2070 - val_loss: 33.8873 - 727ms/epoch - 8ms/step
# Epoch 107/1000
# 88/88 - 1s - loss: 28.0892 - val_loss: 34.4811 - 737ms/epoch - 8ms/step
# Epoch 108/1000
# 88/88 - 1s - loss: 28.0228 - val_loss: 34.5271 - 743ms/epoch - 8ms/step
# Epoch 109/1000
# 88/88 - 1s - loss: 27.7848 - val_loss: 34.2305 - 745ms/epoch - 8ms/step
# Epoch 110/1000
# 88/88 - 1s - loss: 27.8587 - val_loss: 34.6194 - 812ms/epoch - 9ms/step
# Epoch 111/1000
# 88/88 - 1s - loss: 27.8388 - val_loss: 34.5243 - 796ms/epoch - 9ms/step
# Epoch 112/1000
# 88/88 - 1s - loss: 28.0688 - val_loss: 33.5401 - 770ms/epoch - 9ms/step
# Epoch 113/1000
# 88/88 - 1s - loss: 27.7845 - val_loss: 34.0820 - 740ms/epoch - 8ms/step
# Epoch 114/1000
# 88/88 - 1s - loss: 27.7765 - val_loss: 34.4212 - 753ms/epoch - 9ms/step
# Epoch 115/1000
# 88/88 - 1s - loss: 27.8124 - val_loss: 33.6318 - 699ms/epoch - 8ms/step
# Epoch 116/1000
# 88/88 - 1s - loss: 27.6606 - val_loss: 34.2813 - 738ms/epoch - 8ms/step
# Epoch 117/1000
# 88/88 - 1s - loss: 27.6825 - val_loss: 33.7876 - 783ms/epoch - 9ms/step
# Epoch 118/1000
# 88/88 - 1s - loss: 27.5429 - val_loss: 33.6638 - 707ms/epoch - 8ms/step
# Epoch 119/1000
# 88/88 - 1s - loss: 27.5298 - val_loss: 34.4511 - 757ms/epoch - 9ms/step
# Epoch 120/1000
# 88/88 - 1s - loss: 27.8587 - val_loss: 34.0491 - 718ms/epoch - 8ms/step
# Epoch 121/1000
# 88/88 - 1s - loss: 27.4920 - val_loss: 34.6062 - 743ms/epoch - 8ms/step
# Epoch 122/1000
# 88/88 - 1s - loss: 27.2460 - val_loss: 34.4238 - 797ms/epoch - 9ms/step
# Epoch 123/1000
# 88/88 - 1s - loss: 27.4558 - val_loss: 33.9487 - 760ms/epoch - 9ms/step
# Epoch 124/1000
# 88/88 - 1s - loss: 27.3637 - val_loss: 34.3696 - 809ms/epoch - 9ms/step
# Epoch 125/1000
# 88/88 - 1s - loss: 27.1476 - val_loss: 34.8033 - 780ms/epoch - 9ms/step
# Epoch 126/1000
# 88/88 - 1s - loss: 27.2285 - val_loss: 34.5093 - 748ms/epoch - 8ms/step
# Epoch 127/1000
# 88/88 - 1s - loss: 27.3180 - val_loss: 34.6651 - 742ms/epoch - 8ms/step
# Epoch 128/1000
# 88/88 - 1s - loss: 27.1506 - val_loss: 34.5032 - 752ms/epoch - 9ms/step
# Epoch 129/1000
# 88/88 - 1s - loss: 27.0963 - val_loss: 35.1309 - 810ms/epoch - 9ms/step
# Epoch 130/1000
# 88/88 - 1s - loss: 27.3361 - val_loss: 34.5580 - 747ms/epoch - 8ms/step
# Epoch 131/1000
# 88/88 - 1s - loss: 26.8880 - val_loss: 35.9805 - 754ms/epoch - 9ms/step
# Epoch 132/1000
# 88/88 - 1s - loss: 27.2647 - val_loss: 34.0009 - 732ms/epoch - 8ms/step
# Epoch 133/1000
# 88/88 - 1s - loss: 26.9391 - val_loss: 34.6913 - 743ms/epoch - 8ms/step
# Epoch 134/1000
# 88/88 - 1s - loss: 27.2395 - val_loss: 35.1447 - 742ms/epoch - 8ms/step
# Epoch 135/1000
# 88/88 - 1s - loss: 26.9383 - val_loss: 33.9626 - 722ms/epoch - 8ms/step
# Epoch 136/1000
# 88/88 - 1s - loss: 26.9238 - val_loss: 34.2984 - 724ms/epoch - 8ms/step
# Epoch 137/1000
# 88/88 - 1s - loss: 26.9691 - val_loss: 34.3375 - 748ms/epoch - 9ms/step
# Epoch 138/1000
# 88/88 - 1s - loss: 26.9516 - val_loss: 34.5065 - 748ms/epoch - 9ms/step
# Epoch 139/1000
# 88/88 - 1s - loss: 26.8111 - val_loss: 35.0842 - 751ms/epoch - 9ms/step
# Epoch 140/1000
# 88/88 - 1s - loss: 27.0114 - val_loss: 34.7707 - 809ms/epoch - 9ms/step
# Epoch 141/1000
# 88/88 - 1s - loss: 26.9620 - val_loss: 34.6744 - 733ms/epoch - 8ms/step
# Epoch 142/1000
# 88/88 - 1s - loss: 27.1094 - val_loss: 34.1028 - 756ms/epoch - 9ms/step
# Epoch 143/1000
# 88/88 - 1s - loss: 26.6414 - val_loss: 34.1298 - 798ms/epoch - 9ms/step
# Epoch 144/1000
# 88/88 - 1s - loss: 26.9040 - val_loss: 34.7078 - 754ms/epoch - 9ms/step
# Epoch 145/1000
# 88/88 - 1s - loss: 26.7637 - val_loss: 34.4793 - 814ms/epoch - 9ms/step
# Epoch 146/1000
# 88/88 - 1s - loss: 26.6156 - val_loss: 36.3409 - 727ms/epoch - 8ms/step
# Epoch 147/1000
# 88/88 - 1s - loss: 26.6908 - val_loss: 35.1160 - 743ms/epoch - 8ms/step
# Epoch 148/1000
# 88/88 - 1s - loss: 26.9620 - val_loss: 34.3234 - 726ms/epoch - 8ms/step
# Epoch 149/1000
# 88/88 - 1s - loss: 26.5987 - val_loss: 35.2254 - 731ms/epoch - 8ms/step
# Epoch 150/1000
# 88/88 - 1s - loss: 26.5257 - val_loss: 34.7727 - 804ms/epoch - 9ms/step
# Epoch 151/1000
# 88/88 - 1s - loss: 26.5405 - val_loss: 35.2625 - 727ms/epoch - 8ms/step
# Epoch 152/1000
# 88/88 - 1s - loss: 26.5752 - val_loss: 35.0931 - 758ms/epoch - 9ms/step
# Epoch 153/1000
# 88/88 - 1s - loss: 26.4749 - val_loss: 34.7051 - 807ms/epoch - 9ms/step
# Epoch 154/1000
# 88/88 - 1s - loss: 26.4697 - val_loss: 35.8876 - 785ms/epoch - 9ms/step
# Epoch 155/1000
# 88/88 - 1s - loss: 26.5953 - val_loss: 34.4605 - 781ms/epoch - 9ms/step
# Epoch 156/1000
# 88/88 - 1s - loss: 26.4981 - val_loss: 35.1112 - 791ms/epoch - 9ms/step
# Epoch 157/1000
# 88/88 - 1s - loss: 26.6026 - val_loss: 34.7282 - 731ms/epoch - 8ms/step
# Epoch 158/1000
# 88/88 - 1s - loss: 26.4343 - val_loss: 34.7630 - 803ms/epoch - 9ms/step
# Epoch 159/1000
# 88/88 - 1s - loss: 26.2618 - val_loss: 34.7558 - 728ms/epoch - 8ms/step
# Epoch 160/1000
# 88/88 - 1s - loss: 26.2759 - val_loss: 34.8540 - 724ms/epoch - 8ms/step
# Epoch 161/1000
# 88/88 - 1s - loss: 26.2873 - val_loss: 34.8906 - 749ms/epoch - 9ms/step
# Epoch 162/1000
# 88/88 - 1s - loss: 26.2074 - val_loss: 34.7049 - 730ms/epoch - 8ms/step
# Epoch 163/1000
# 88/88 - 1s - loss: 26.2042 - val_loss: 35.0182 - 779ms/epoch - 9ms/step
# Epoch 164/1000
# 88/88 - 1s - loss: 26.0234 - val_loss: 36.3351 - 811ms/epoch - 9ms/step
# Epoch 165/1000
# 88/88 - 1s - loss: 26.2870 - val_loss: 34.8838 - 843ms/epoch - 10ms/step
# Epoch 166/1000
# 88/88 - 1s - loss: 26.0760 - val_loss: 35.4286 - 819ms/epoch - 9ms/step
# Epoch 167/1000
# 88/88 - 1s - loss: 26.1863 - val_loss: 35.5655 - 765ms/epoch - 9ms/step
# Epoch 168/1000
# 88/88 - 1s - loss: 26.1265 - val_loss: 34.6266 - 771ms/epoch - 9ms/step
# Epoch 169/1000
# 88/88 - 1s - loss: 25.9711 - val_loss: 35.5828 - 774ms/epoch - 9ms/step
# Epoch 170/1000
# 88/88 - 1s - loss: 26.1817 - val_loss: 34.8031 - 757ms/epoch - 9ms/step
# Epoch 171/1000
# 88/88 - 1s - loss: 26.0253 - val_loss: 36.1677 - 766ms/epoch - 9ms/step
# Epoch 172/1000
# 88/88 - 1s - loss: 25.7663 - val_loss: 35.6125 - 742ms/epoch - 8ms/step
# Epoch 173/1000
# 88/88 - 1s - loss: 25.8318 - val_loss: 34.7302 - 768ms/epoch - 9ms/step
# Epoch 174/1000
# 88/88 - 1s - loss: 25.8773 - val_loss: 36.2726 - 754ms/epoch - 9ms/step
# Epoch 175/1000
# 88/88 - 1s - loss: 26.0850 - val_loss: 35.4078 - 751ms/epoch - 9ms/step
# Epoch 176/1000
# 88/88 - 1s - loss: 25.9551 - val_loss: 35.6806 - 788ms/epoch - 9ms/step
# Epoch 177/1000
# 88/88 - 1s - loss: 25.8149 - val_loss: 35.6000 - 748ms/epoch - 8ms/step
# Epoch 178/1000
# 88/88 - 1s - loss: 25.7378 - val_loss: 35.1245 - 739ms/epoch - 8ms/step
# Epoch 179/1000
# 88/88 - 1s - loss: 25.6165 - val_loss: 35.5666 - 802ms/epoch - 9ms/step
# Epoch 180/1000
# 88/88 - 1s - loss: 25.6358 - val_loss: 34.8760 - 743ms/epoch - 8ms/step
# Epoch 181/1000
# 88/88 - 1s - loss: 25.6650 - val_loss: 36.2354 - 763ms/epoch - 9ms/step
# Epoch 182/1000
# 88/88 - 1s - loss: 25.5661 - val_loss: 35.6668 - 743ms/epoch - 8ms/step
# Epoch 183/1000
# 88/88 - 1s - loss: 25.5141 - val_loss: 36.3116 - 783ms/epoch - 9ms/step
# Epoch 184/1000
# 88/88 - 1s - loss: 25.7004 - val_loss: 36.5018 - 753ms/epoch - 9ms/step
# Epoch 185/1000
# 88/88 - 1s - loss: 25.7603 - val_loss: 35.6631 - 760ms/epoch - 9ms/step
# Epoch 186/1000
# 88/88 - 1s - loss: 25.6202 - val_loss: 35.5199 - 782ms/epoch - 9ms/step
# Epoch 187/1000
# 88/88 - 1s - loss: 25.5506 - val_loss: 35.9928 - 791ms/epoch - 9ms/step
# Epoch 188/1000
# 88/88 - 1s - loss: 25.5903 - val_loss: 35.2745 - 783ms/epoch - 9ms/step
# Epoch 189/1000
# 88/88 - 1s - loss: 25.2269 - val_loss: 35.2821 - 802ms/epoch - 9ms/step
# Epoch 190/1000
# 88/88 - 1s - loss: 25.5122 - val_loss: 35.4280 - 828ms/epoch - 9ms/step
# Epoch 191/1000
# 88/88 - 1s - loss: 25.5105 - val_loss: 37.1157 - 745ms/epoch - 8ms/step
# Epoch 192/1000
# 88/88 - 1s - loss: 25.5134 - val_loss: 35.5368 - 739ms/epoch - 8ms/step
# Epoch 193/1000
# 88/88 - 1s - loss: 25.2285 - val_loss: 36.2263 - 748ms/epoch - 8ms/step
# Epoch 194/1000
# 88/88 - 1s - loss: 25.3757 - val_loss: 35.5367 - 728ms/epoch - 8ms/step
# Epoch 195/1000
# 88/88 - 1s - loss: 25.4858 - val_loss: 35.9231 - 736ms/epoch - 8ms/step
# Epoch 196/1000
# 88/88 - 1s - loss: 25.5680 - val_loss: 36.1953 - 809ms/epoch - 9ms/step
# Epoch 197/1000
# 88/88 - 1s - loss: 25.5081 - val_loss: 35.6726 - 821ms/epoch - 9ms/step
# Epoch 198/1000
# 88/88 - 1s - loss: 25.1880 - val_loss: 35.6431 - 731ms/epoch - 8ms/step
# Epoch 199/1000
# 88/88 - 1s - loss: 25.2401 - val_loss: 35.3953 - 751ms/epoch - 9ms/step
# Epoch 200/1000
# 88/88 - 1s - loss: 25.4334 - val_loss: 36.2215 - 732ms/epoch - 8ms/step
# Epoch 201/1000
# 88/88 - 1s - loss: 25.1922 - val_loss: 35.8043 - 795ms/epoch - 9ms/step
# Epoch 202/1000
# 88/88 - 1s - loss: 25.4726 - val_loss: 35.1285 - 781ms/epoch - 9ms/step
# Epoch 203/1000
# 88/88 - 1s - loss: 25.3583 - val_loss: 35.0989 - 723ms/epoch - 8ms/step
# Epoch 204/1000
# 88/88 - 1s - loss: 25.3705 - val_loss: 35.9836 - 738ms/epoch - 8ms/step
# Epoch 205/1000
# 88/88 - 1s - loss: 25.0431 - val_loss: 36.0423 - 734ms/epoch - 8ms/step
# Epoch 206/1000
# 88/88 - 1s - loss: 25.1362 - val_loss: 35.8489 - 742ms/epoch - 8ms/step
# Epoch 207/1000
# 88/88 - 1s - loss: 25.0531 - val_loss: 35.8905 - 747ms/epoch - 8ms/step
# Epoch 208/1000
# 88/88 - 1s - loss: 25.0213 - val_loss: 36.1216 - 781ms/epoch - 9ms/step
# Epoch 209/1000
# 88/88 - 1s - loss: 25.0052 - val_loss: 35.7329 - 768ms/epoch - 9ms/step
# Epoch 210/1000
# 88/88 - 1s - loss: 24.8567 - val_loss: 35.4904 - 737ms/epoch - 8ms/step
# Epoch 211/1000
# 88/88 - 1s - loss: 24.9291 - val_loss: 35.7400 - 757ms/epoch - 9ms/step
# Epoch 212/1000
# 88/88 - 1s - loss: 25.1330 - val_loss: 35.3004 - 726ms/epoch - 8ms/step
# Epoch 213/1000
# 88/88 - 1s - loss: 25.0430 - val_loss: 35.5939 - 755ms/epoch - 9ms/step
# Epoch 214/1000
# 88/88 - 1s - loss: 24.9482 - val_loss: 35.3787 - 734ms/epoch - 8ms/step
# Epoch 215/1000
# 88/88 - 1s - loss: 24.7942 - val_loss: 35.7578 - 759ms/epoch - 9ms/step
# Epoch 216/1000
# 88/88 - 1s - loss: 24.9189 - val_loss: 35.4381 - 755ms/epoch - 9ms/step
# Epoch 217/1000
# 88/88 - 1s - loss: 24.6726 - val_loss: 35.8314 - 734ms/epoch - 8ms/step
# Epoch 218/1000
# 88/88 - 1s - loss: 24.6132 - val_loss: 36.2947 - 765ms/epoch - 9ms/step
# Epoch 219/1000
# 88/88 - 1s - loss: 24.9276 - val_loss: 36.4764 - 798ms/epoch - 9ms/step
# Epoch 220/1000
# 88/88 - 1s - loss: 24.9696 - val_loss: 36.2110 - 744ms/epoch - 8ms/step
# Epoch 221/1000
# 88/88 - 1s - loss: 24.4128 - val_loss: 36.0396 - 804ms/epoch - 9ms/step
# Epoch 222/1000
# 88/88 - 1s - loss: 24.6284 - val_loss: 36.3693 - 774ms/epoch - 9ms/step
# Epoch 223/1000
# 88/88 - 1s - loss: 24.5412 - val_loss: 35.9306 - 726ms/epoch - 8ms/step
# Epoch 224/1000
# 88/88 - 1s - loss: 24.4588 - val_loss: 36.0639 - 730ms/epoch - 8ms/step
# Epoch 225/1000
# 88/88 - 1s - loss: 24.4863 - val_loss: 35.6025 - 755ms/epoch - 9ms/step
# Epoch 226/1000
# 88/88 - 1s - loss: 24.6244 - val_loss: 35.7853 - 787ms/epoch - 9ms/step
# Epoch 227/1000
# 88/88 - 1s - loss: 24.8440 - val_loss: 36.5146 - 786ms/epoch - 9ms/step
# Epoch 228/1000
# 88/88 - 1s - loss: 24.3678 - val_loss: 35.9511 - 749ms/epoch - 9ms/step
# Epoch 229/1000
# 88/88 - 1s - loss: 24.2314 - val_loss: 35.7586 - 716ms/epoch - 8ms/step
# Epoch 230/1000
# 88/88 - 1s - loss: 24.3184 - val_loss: 36.0710 - 741ms/epoch - 8ms/step
# Epoch 231/1000
# 88/88 - 1s - loss: 24.3999 - val_loss: 36.2557 - 823ms/epoch - 9ms/step
# Epoch 232/1000
# 88/88 - 1s - loss: 24.4309 - val_loss: 36.1494 - 801ms/epoch - 9ms/step
# Epoch 233/1000
# 88/88 - 1s - loss: 24.6033 - val_loss: 36.2584 - 721ms/epoch - 8ms/step
# Epoch 234/1000
# 88/88 - 1s - loss: 24.5058 - val_loss: 36.0544 - 718ms/epoch - 8ms/step
# Epoch 235/1000
# 88/88 - 1s - loss: 24.4062 - val_loss: 36.3211 - 721ms/epoch - 8ms/step
# Epoch 236/1000
# 88/88 - 1s - loss: 24.1699 - val_loss: 36.4429 - 721ms/epoch - 8ms/step
# Epoch 237/1000
# 88/88 - 1s - loss: 24.1777 - val_loss: 36.1936 - 746ms/epoch - 8ms/step
# Epoch 238/1000
# 88/88 - 1s - loss: 24.6685 - val_loss: 35.8448 - 802ms/epoch - 9ms/step
# Epoch 239/1000
# 88/88 - 1s - loss: 24.5003 - val_loss: 36.2162 - 814ms/epoch - 9ms/step
# Epoch 240/1000
# 88/88 - 1s - loss: 24.3470 - val_loss: 35.7532 - 805ms/epoch - 9ms/step
# Epoch 241/1000
# 88/88 - 1s - loss: 24.2202 - val_loss: 36.5877 - 804ms/epoch - 9ms/step
# Epoch 242/1000
# 88/88 - 1s - loss: 24.3268 - val_loss: 35.5330 - 825ms/epoch - 9ms/step
# Epoch 243/1000
# 88/88 - 1s - loss: 24.2926 - val_loss: 36.5114 - 755ms/epoch - 9ms/step
# Epoch 244/1000
# 88/88 - 1s - loss: 24.1572 - val_loss: 36.6287 - 803ms/epoch - 9ms/step
# Epoch 245/1000
# 88/88 - 1s - loss: 24.2951 - val_loss: 36.8470 - 781ms/epoch - 9ms/step
# Epoch 246/1000
# 88/88 - 1s - loss: 24.3346 - val_loss: 36.6078 - 797ms/epoch - 9ms/step
# Epoch 247/1000
# 88/88 - 1s - loss: 24.1152 - val_loss: 36.4217 - 749ms/epoch - 9ms/step
# Epoch 248/1000
# 88/88 - 1s - loss: 24.1983 - val_loss: 36.5923 - 729ms/epoch - 8ms/step
# Epoch 249/1000
# 88/88 - 1s - loss: 23.9310 - val_loss: 36.6391 - 743ms/epoch - 8ms/step
# Epoch 250/1000
# 88/88 - 1s - loss: 24.0737 - val_loss: 36.1240 - 792ms/epoch - 9ms/step
# Epoch 251/1000
# 88/88 - 1s - loss: 24.0536 - val_loss: 36.4013 - 809ms/epoch - 9ms/step
# Epoch 252/1000
# 88/88 - 1s - loss: 23.8811 - val_loss: 36.0921 - 790ms/epoch - 9ms/step
# Epoch 253/1000
# 88/88 - 1s - loss: 23.9714 - val_loss: 36.0999 - 812ms/epoch - 9ms/step
# Epoch 254/1000
# 88/88 - 1s - loss: 23.8259 - val_loss: 36.6251 - 734ms/epoch - 8ms/step
# Epoch 255/1000
# 88/88 - 1s - loss: 23.5138 - val_loss: 36.6925 - 794ms/epoch - 9ms/step
# Epoch 256/1000
# 88/88 - 1s - loss: 24.1165 - val_loss: 36.2803 - 795ms/epoch - 9ms/step
# Epoch 257/1000
# 88/88 - 1s - loss: 24.1143 - val_loss: 36.2053 - 789ms/epoch - 9ms/step
# Epoch 258/1000
# 88/88 - 1s - loss: 23.7318 - val_loss: 36.0115 - 805ms/epoch - 9ms/step
# Epoch 259/1000
# 88/88 - 1s - loss: 23.5533 - val_loss: 36.3148 - 749ms/epoch - 9ms/step
# Epoch 260/1000
# 88/88 - 1s - loss: 23.5777 - val_loss: 37.3170 - 743ms/epoch - 8ms/step
# Epoch 261/1000
# 88/88 - 1s - loss: 24.2596 - val_loss: 36.1976 - 749ms/epoch - 9ms/step
# Epoch 262/1000
# 88/88 - 1s - loss: 23.9093 - val_loss: 36.7953 - 806ms/epoch - 9ms/step
# Epoch 263/1000
# 88/88 - 1s - loss: 23.7827 - val_loss: 37.7358 - 725ms/epoch - 8ms/step
# Epoch 264/1000
# 88/88 - 1s - loss: 23.7297 - val_loss: 36.5868 - 757ms/epoch - 9ms/step
# Epoch 265/1000
# 88/88 - 1s - loss: 23.7003 - val_loss: 36.2058 - 734ms/epoch - 8ms/step
# Epoch 266/1000
# 88/88 - 1s - loss: 23.7654 - val_loss: 36.6472 - 695ms/epoch - 8ms/step
# Epoch 267/1000
# 88/88 - 1s - loss: 24.1895 - val_loss: 36.3499 - 726ms/epoch - 8ms/step
# Epoch 268/1000
# 88/88 - 1s - loss: 23.7048 - val_loss: 36.1930 - 769ms/epoch - 9ms/step
# Epoch 269/1000
# 88/88 - 1s - loss: 23.8392 - val_loss: 36.2337 - 801ms/epoch - 9ms/step
# Epoch 270/1000
# 88/88 - 1s - loss: 24.1063 - val_loss: 36.5846 - 715ms/epoch - 8ms/step
# Epoch 271/1000
# 88/88 - 1s - loss: 24.0854 - val_loss: 36.9924 - 728ms/epoch - 8ms/step
# Epoch 272/1000
# 88/88 - 1s - loss: 23.6682 - val_loss: 35.8811 - 750ms/epoch - 9ms/step
# Epoch 273/1000
# 88/88 - 1s - loss: 23.4551 - val_loss: 36.3120 - 759ms/epoch - 9ms/step
# Epoch 274/1000
# 88/88 - 1s - loss: 23.3635 - val_loss: 36.6595 - 716ms/epoch - 8ms/step
# Epoch 275/1000
# 88/88 - 1s - loss: 23.4953 - val_loss: 35.8732 - 774ms/epoch - 9ms/step
# Epoch 276/1000
# 88/88 - 1s - loss: 23.5253 - val_loss: 36.6797 - 749ms/epoch - 9ms/step
# Epoch 277/1000
# 88/88 - 1s - loss: 23.7460 - val_loss: 35.9598 - 772ms/epoch - 9ms/step
# Epoch 278/1000
# 88/88 - 1s - loss: 23.6158 - val_loss: 36.4958 - 825ms/epoch - 9ms/step
# Epoch 279/1000
# 88/88 - 1s - loss: 23.7657 - val_loss: 36.8446 - 742ms/epoch - 8ms/step
# Epoch 280/1000
# 88/88 - 1s - loss: 23.4987 - val_loss: 37.1838 - 764ms/epoch - 9ms/step
# Epoch 281/1000
# 88/88 - 1s - loss: 23.5263 - val_loss: 36.9842 - 746ms/epoch - 8ms/step
# Epoch 282/1000
# 88/88 - 1s - loss: 23.4863 - val_loss: 36.7930 - 796ms/epoch - 9ms/step
# Epoch 283/1000
# 88/88 - 1s - loss: 23.6152 - val_loss: 37.1075 - 795ms/epoch - 9ms/step
# Epoch 284/1000
# 88/88 - 1s - loss: 23.5989 - val_loss: 36.2303 - 738ms/epoch - 8ms/step
# Epoch 285/1000
# 88/88 - 1s - loss: 23.5019 - val_loss: 36.6367 - 797ms/epoch - 9ms/step
# Epoch 286/1000
# 88/88 - 1s - loss: 23.3169 - val_loss: 36.9276 - 793ms/epoch - 9ms/step
# Epoch 287/1000
# 88/88 - 1s - loss: 23.5309 - val_loss: 36.3076 - 730ms/epoch - 8ms/step
# Epoch 288/1000
# 88/88 - 1s - loss: 23.6307 - val_loss: 37.2546 - 746ms/epoch - 8ms/step
# Epoch 289/1000
# 88/88 - 1s - loss: 23.2850 - val_loss: 36.3972 - 751ms/epoch - 9ms/step
# Epoch 290/1000
# 88/88 - 1s - loss: 23.0061 - val_loss: 36.5683 - 740ms/epoch - 8ms/step
# Epoch 291/1000
# 88/88 - 1s - loss: 23.1856 - val_loss: 37.3264 - 812ms/epoch - 9ms/step
# Epoch 292/1000
# 88/88 - 1s - loss: 23.1224 - val_loss: 36.0635 - 771ms/epoch - 9ms/step
# Epoch 293/1000
# 88/88 - 1s - loss: 23.0923 - val_loss: 37.2559 - 733ms/epoch - 8ms/step
# Epoch 294/1000
# 88/88 - 1s - loss: 23.4451 - val_loss: 36.3420 - 773ms/epoch - 9ms/step
# Epoch 295/1000
# 88/88 - 1s - loss: 23.2117 - val_loss: 35.9991 - 812ms/epoch - 9ms/step
# Epoch 296/1000
# 88/88 - 1s - loss: 23.2419 - val_loss: 36.5731 - 807ms/epoch - 9ms/step
# Epoch 297/1000
# 88/88 - 1s - loss: 23.3639 - val_loss: 37.0710 - 742ms/epoch - 8ms/step
# Epoch 298/1000
# 88/88 - 1s - loss: 23.1530 - val_loss: 36.3218 - 758ms/epoch - 9ms/step
# Epoch 299/1000
# 88/88 - 1s - loss: 23.3165 - val_loss: 36.9486 - 751ms/epoch - 9ms/step
# Epoch 300/1000
# 88/88 - 1s - loss: 23.0471 - val_loss: 36.3781 - 743ms/epoch - 8ms/step
# Epoch 301/1000
# 88/88 - 1s - loss: 23.0111 - val_loss: 35.9341 - 744ms/epoch - 8ms/step
# Epoch 302/1000
# 88/88 - 1s - loss: 23.0801 - val_loss: 36.4939 - 798ms/epoch - 9ms/step
# Epoch 303/1000
# 88/88 - 1s - loss: 23.0249 - val_loss: 36.7585 - 746ms/epoch - 8ms/step
# Epoch 304/1000
# 88/88 - 1s - loss: 23.0663 - val_loss: 36.7902 - 788ms/epoch - 9ms/step
# Epoch 305/1000
# 88/88 - 1s - loss: 22.9096 - val_loss: 36.8189 - 716ms/epoch - 8ms/step
# Epoch 306/1000
# 88/88 - 1s - loss: 23.1064 - val_loss: 36.4874 - 727ms/epoch - 8ms/step
# Epoch 307/1000
# 88/88 - 1s - loss: 23.0835 - val_loss: 35.9913 - 768ms/epoch - 9ms/step
# Epoch 308/1000
# 88/88 - 1s - loss: 22.7127 - val_loss: 36.3517 - 696ms/epoch - 8ms/step
# Epoch 309/1000
# 88/88 - 1s - loss: 22.9621 - val_loss: 36.7604 - 717ms/epoch - 8ms/step
# Epoch 310/1000
# 88/88 - 1s - loss: 23.0174 - val_loss: 36.0026 - 704ms/epoch - 8ms/step
# Epoch 311/1000
# 88/88 - 1s - loss: 22.7560 - val_loss: 37.2977 - 732ms/epoch - 8ms/step
# Epoch 312/1000
# 88/88 - 1s - loss: 23.3219 - val_loss: 36.1022 - 729ms/epoch - 8ms/step
# Epoch 313/1000
# 88/88 - 1s - loss: 23.0305 - val_loss: 36.9937 - 730ms/epoch - 8ms/step
# Epoch 314/1000
# 88/88 - 1s - loss: 22.9309 - val_loss: 36.9916 - 785ms/epoch - 9ms/step
# Epoch 315/1000
# 88/88 - 1s - loss: 22.7685 - val_loss: 36.9289 - 730ms/epoch - 8ms/step
# Epoch 316/1000
# 88/88 - 1s - loss: 22.7351 - val_loss: 36.7776 - 726ms/epoch - 8ms/step
# Epoch 317/1000
# 88/88 - 1s - loss: 22.7413 - val_loss: 37.2202 - 735ms/epoch - 8ms/step
# Epoch 318/1000
# 88/88 - 1s - loss: 22.7443 - val_loss: 36.9439 - 784ms/epoch - 9ms/step
# Epoch 319/1000
# 88/88 - 1s - loss: 22.9063 - val_loss: 36.8470 - 730ms/epoch - 8ms/step
# Epoch 320/1000
# 88/88 - 1s - loss: 22.9793 - val_loss: 37.0525 - 784ms/epoch - 9ms/step
# Epoch 321/1000
# 88/88 - 1s - loss: 22.9558 - val_loss: 36.6032 - 713ms/epoch - 8ms/step
# Epoch 322/1000
# 88/88 - 1s - loss: 22.5818 - val_loss: 36.5316 - 777ms/epoch - 9ms/step
# Epoch 323/1000
# 88/88 - 1s - loss: 22.7707 - val_loss: 36.2070 - 777ms/epoch - 9ms/step
# Epoch 324/1000
# 88/88 - 1s - loss: 22.6777 - val_loss: 36.7966 - 714ms/epoch - 8ms/step
# Epoch 325/1000
# 88/88 - 1s - loss: 22.5198 - val_loss: 36.9549 - 747ms/epoch - 8ms/step
# Epoch 326/1000
# 88/88 - 1s - loss: 22.8734 - val_loss: 36.6811 - 756ms/epoch - 9ms/step
# Epoch 327/1000
# 88/88 - 1s - loss: 22.5542 - val_loss: 36.7182 - 749ms/epoch - 9ms/step
# Epoch 328/1000
# 88/88 - 1s - loss: 22.6667 - val_loss: 36.2986 - 723ms/epoch - 8ms/step
# Epoch 329/1000
# 88/88 - 1s - loss: 22.7110 - val_loss: 37.2374 - 715ms/epoch - 8ms/step
# Epoch 330/1000
# 88/88 - 1s - loss: 22.5882 - val_loss: 36.4636 - 711ms/epoch - 8ms/step
# Epoch 331/1000
# 88/88 - 1s - loss: 22.6457 - val_loss: 37.2683 - 778ms/epoch - 9ms/step
# Epoch 332/1000
# 88/88 - 1s - loss: 22.8655 - val_loss: 37.1776 - 715ms/epoch - 8ms/step
# Epoch 333/1000
# 88/88 - 1s - loss: 22.7444 - val_loss: 37.0846 - 720ms/epoch - 8ms/step
# Epoch 334/1000
# 88/88 - 1s - loss: 22.5533 - val_loss: 37.1202 - 730ms/epoch - 8ms/step
# Epoch 335/1000
# 88/88 - 1s - loss: 22.7838 - val_loss: 36.6336 - 722ms/epoch - 8ms/step
# Epoch 336/1000
# 88/88 - 1s - loss: 22.7136 - val_loss: 36.6878 - 768ms/epoch - 9ms/step
# Epoch 337/1000
# 88/88 - 1s - loss: 22.3286 - val_loss: 36.8121 - 772ms/epoch - 9ms/step
# Epoch 338/1000
# 88/88 - 1s - loss: 22.6976 - val_loss: 37.6479 - 717ms/epoch - 8ms/step
# Epoch 339/1000
# 88/88 - 1s - loss: 22.5806 - val_loss: 36.3919 - 745ms/epoch - 8ms/step
# Epoch 340/1000
# 88/88 - 1s - loss: 22.5814 - val_loss: 36.5930 - 721ms/epoch - 8ms/step
# Epoch 341/1000
# 88/88 - 1s - loss: 22.6603 - val_loss: 36.4975 - 774ms/epoch - 9ms/step
# Epoch 342/1000
# 88/88 - 1s - loss: 22.4082 - val_loss: 37.5525 - 724ms/epoch - 8ms/step
# Epoch 343/1000
# 88/88 - 1s - loss: 22.3250 - val_loss: 37.4710 - 736ms/epoch - 8ms/step
# Epoch 344/1000
# 88/88 - 1s - loss: 22.2071 - val_loss: 37.2531 - 723ms/epoch - 8ms/step
# Epoch 345/1000
# 88/88 - 1s - loss: 22.4223 - val_loss: 37.3740 - 741ms/epoch - 8ms/step
# Epoch 346/1000
# 88/88 - 1s - loss: 22.2466 - val_loss: 37.0081 - 790ms/epoch - 9ms/step
# Epoch 347/1000
# 88/88 - 1s - loss: 21.9868 - val_loss: 36.5629 - 749ms/epoch - 9ms/step
# Epoch 348/1000
# 88/88 - 1s - loss: 22.2283 - val_loss: 38.2441 - 773ms/epoch - 9ms/step
# Epoch 349/1000
# 88/88 - 1s - loss: 22.4763 - val_loss: 36.9958 - 798ms/epoch - 9ms/step
# Epoch 350/1000
# 88/88 - 1s - loss: 22.2964 - val_loss: 37.0051 - 735ms/epoch - 8ms/step
# Epoch 351/1000
# 88/88 - 1s - loss: 22.3395 - val_loss: 37.4911 - 719ms/epoch - 8ms/step
# Epoch 352/1000
# 88/88 - 1s - loss: 22.2704 - val_loss: 37.0769 - 733ms/epoch - 8ms/step
# Epoch 353/1000
# 88/88 - 1s - loss: 22.0771 - val_loss: 37.8263 - 730ms/epoch - 8ms/step
# Epoch 354/1000
# 88/88 - 1s - loss: 22.2733 - val_loss: 36.8858 - 788ms/epoch - 9ms/step
# Epoch 355/1000
# 88/88 - 1s - loss: 22.1976 - val_loss: 37.0617 - 755ms/epoch - 9ms/step
# Epoch 356/1000
# 88/88 - 1s - loss: 22.3187 - val_loss: 37.0009 - 683ms/epoch - 8ms/step
# Epoch 357/1000
# 88/88 - 1s - loss: 22.2110 - val_loss: 37.0075 - 717ms/epoch - 8ms/step
# Epoch 358/1000
# 88/88 - 1s - loss: 22.1108 - val_loss: 36.3852 - 787ms/epoch - 9ms/step
# Epoch 359/1000
# 88/88 - 1s - loss: 22.2079 - val_loss: 37.1352 - 734ms/epoch - 8ms/step
# Epoch 360/1000
# 88/88 - 1s - loss: 22.0182 - val_loss: 37.5257 - 729ms/epoch - 8ms/step
# Epoch 361/1000
# 88/88 - 1s - loss: 21.9694 - val_loss: 37.4956 - 721ms/epoch - 8ms/step
# Epoch 362/1000
# 88/88 - 1s - loss: 21.8756 - val_loss: 37.0595 - 723ms/epoch - 8ms/step
# Epoch 363/1000
# 88/88 - 1s - loss: 22.1355 - val_loss: 36.6109 - 708ms/epoch - 8ms/step
# Epoch 364/1000
# 88/88 - 1s - loss: 22.2231 - val_loss: 37.6036 - 724ms/epoch - 8ms/step
# Epoch 365/1000
# 88/88 - 1s - loss: 22.2125 - val_loss: 36.9107 - 729ms/epoch - 8ms/step
# Epoch 366/1000
# 88/88 - 1s - loss: 22.0222 - val_loss: 37.3365 - 724ms/epoch - 8ms/step
# Epoch 367/1000
# 88/88 - 1s - loss: 21.9596 - val_loss: 37.1219 - 719ms/epoch - 8ms/step
# Epoch 368/1000
# 88/88 - 1s - loss: 21.9760 - val_loss: 36.2817 - 727ms/epoch - 8ms/step
# Epoch 369/1000
# 88/88 - 1s - loss: 22.1671 - val_loss: 37.4171 - 741ms/epoch - 8ms/step
# Epoch 370/1000
# 88/88 - 1s - loss: 22.2883 - val_loss: 37.6767 - 786ms/epoch - 9ms/step
# Epoch 371/1000
# 88/88 - 1s - loss: 22.0229 - val_loss: 37.6248 - 734ms/epoch - 8ms/step
# Epoch 372/1000
# 88/88 - 1s - loss: 22.0948 - val_loss: 36.9386 - 723ms/epoch - 8ms/step
# Epoch 373/1000
# 88/88 - 1s - loss: 22.2373 - val_loss: 37.3184 - 743ms/epoch - 8ms/step
# Epoch 374/1000
# 88/88 - 1s - loss: 21.8711 - val_loss: 37.1126 - 721ms/epoch - 8ms/step
# Epoch 375/1000
# 88/88 - 1s - loss: 22.0867 - val_loss: 37.2721 - 770ms/epoch - 9ms/step
# Epoch 376/1000
# 88/88 - 1s - loss: 21.8220 - val_loss: 36.9921 - 761ms/epoch - 9ms/step
# Epoch 377/1000
# 88/88 - 1s - loss: 21.9717 - val_loss: 36.9528 - 749ms/epoch - 9ms/step
# Epoch 378/1000
# 88/88 - 1s - loss: 22.2152 - val_loss: 36.4995 - 787ms/epoch - 9ms/step
# Epoch 379/1000
# 88/88 - 1s - loss: 22.1143 - val_loss: 38.0791 - 748ms/epoch - 8ms/step
# Epoch 380/1000
# 88/88 - 1s - loss: 21.7000 - val_loss: 38.4291 - 739ms/epoch - 8ms/step
# Epoch 381/1000
# 88/88 - 1s - loss: 22.3069 - val_loss: 37.4082 - 719ms/epoch - 8ms/step
# Epoch 382/1000
# 88/88 - 1s - loss: 21.7664 - val_loss: 37.7041 - 701ms/epoch - 8ms/step
# Epoch 383/1000
# 88/88 - 1s - loss: 22.1711 - val_loss: 37.0695 - 680ms/epoch - 8ms/step
# Epoch 384/1000
# 88/88 - 1s - loss: 21.8155 - val_loss: 38.0460 - 694ms/epoch - 8ms/step
# Epoch 385/1000
# 88/88 - 1s - loss: 21.7686 - val_loss: 37.6994 - 767ms/epoch - 9ms/step
# Epoch 386/1000
# 88/88 - 1s - loss: 21.8178 - val_loss: 38.0065 - 729ms/epoch - 8ms/step
# Epoch 387/1000
# 88/88 - 1s - loss: 21.8332 - val_loss: 38.4722 - 798ms/epoch - 9ms/step
# Epoch 388/1000
# 88/88 - 1s - loss: 22.0136 - val_loss: 36.9868 - 785ms/epoch - 9ms/step
# Epoch 389/1000
# 88/88 - 1s - loss: 21.8998 - val_loss: 37.3779 - 741ms/epoch - 8ms/step
# Epoch 390/1000
# 88/88 - 1s - loss: 21.9506 - val_loss: 37.9187 - 800ms/epoch - 9ms/step
# Epoch 391/1000
# 88/88 - 1s - loss: 21.7745 - val_loss: 36.8606 - 725ms/epoch - 8ms/step
# Epoch 392/1000
# 88/88 - 1s - loss: 21.9996 - val_loss: 37.5341 - 740ms/epoch - 8ms/step
# Epoch 393/1000
# 88/88 - 1s - loss: 21.8215 - val_loss: 37.8941 - 715ms/epoch - 8ms/step
# Epoch 394/1000
# 88/88 - 1s - loss: 21.8677 - val_loss: 37.2728 - 788ms/epoch - 9ms/step
# Epoch 395/1000
# 88/88 - 1s - loss: 21.5556 - val_loss: 37.3794 - 714ms/epoch - 8ms/step
# Epoch 396/1000
# 88/88 - 1s - loss: 21.5297 - val_loss: 37.7154 - 739ms/epoch - 8ms/step
# Epoch 397/1000
# 88/88 - 1s - loss: 21.7579 - val_loss: 37.9919 - 730ms/epoch - 8ms/step
# Epoch 398/1000
# 88/88 - 1s - loss: 21.3434 - val_loss: 37.1767 - 711ms/epoch - 8ms/step
# Epoch 399/1000
# 88/88 - 1s - loss: 21.4937 - val_loss: 37.3824 - 713ms/epoch - 8ms/step
# Epoch 400/1000
# 88/88 - 1s - loss: 21.4395 - val_loss: 38.4272 - 745ms/epoch - 8ms/step
# Epoch 401/1000
# 88/88 - 1s - loss: 21.7507 - val_loss: 36.7599 - 737ms/epoch - 8ms/step
# Epoch 402/1000
# 88/88 - 1s - loss: 21.6563 - val_loss: 37.5734 - 779ms/epoch - 9ms/step
# Epoch 403/1000
# 88/88 - 1s - loss: 21.5409 - val_loss: 37.0958 - 746ms/epoch - 8ms/step
# Epoch 404/1000
# 88/88 - 1s - loss: 21.6684 - val_loss: 37.8231 - 780ms/epoch - 9ms/step
# Epoch 405/1000
# 88/88 - 1s - loss: 21.6144 - val_loss: 37.1834 - 744ms/epoch - 8ms/step
# Epoch 406/1000
# 88/88 - 1s - loss: 21.4033 - val_loss: 38.2332 - 749ms/epoch - 9ms/step
# Epoch 407/1000
# 88/88 - 1s - loss: 21.4876 - val_loss: 37.4550 - 774ms/epoch - 9ms/step
# Epoch 408/1000
# 88/88 - 1s - loss: 21.5615 - val_loss: 37.3665 - 790ms/epoch - 9ms/step
# Epoch 409/1000
# 88/88 - 1s - loss: 21.3366 - val_loss: 37.4885 - 726ms/epoch - 8ms/step
# Epoch 410/1000
# 88/88 - 1s - loss: 21.6813 - val_loss: 36.8917 - 783ms/epoch - 9ms/step
# Epoch 411/1000
# 88/88 - 1s - loss: 21.7096 - val_loss: 37.5432 - 776ms/epoch - 9ms/step
# Epoch 412/1000
# 88/88 - 1s - loss: 21.5332 - val_loss: 36.9013 - 715ms/epoch - 8ms/step
# Epoch 413/1000
# 88/88 - 1s - loss: 21.3407 - val_loss: 37.6848 - 726ms/epoch - 8ms/step
# Epoch 414/1000
# 88/88 - 1s - loss: 21.6309 - val_loss: 37.6754 - 720ms/epoch - 8ms/step
# Epoch 415/1000
# 88/88 - 1s - loss: 21.4650 - val_loss: 37.3220 - 793ms/epoch - 9ms/step
# Epoch 416/1000
# 88/88 - 1s - loss: 21.4996 - val_loss: 37.5151 - 727ms/epoch - 8ms/step
# Epoch 417/1000
# 88/88 - 1s - loss: 21.2985 - val_loss: 37.6780 - 738ms/epoch - 8ms/step
# Epoch 418/1000
# 88/88 - 1s - loss: 21.3970 - val_loss: 37.8986 - 782ms/epoch - 9ms/step
# Epoch 419/1000
# 88/88 - 1s - loss: 21.4019 - val_loss: 38.2898 - 793ms/epoch - 9ms/step
# Epoch 420/1000
# 88/88 - 1s - loss: 21.3542 - val_loss: 37.4718 - 740ms/epoch - 8ms/step
# Epoch 421/1000
# 88/88 - 1s - loss: 21.5414 - val_loss: 37.1157 - 734ms/epoch - 8ms/step
# Epoch 422/1000
# 88/88 - 1s - loss: 21.1422 - val_loss: 37.8949 - 772ms/epoch - 9ms/step
# Epoch 423/1000
# 88/88 - 1s - loss: 21.4491 - val_loss: 37.8702 - 717ms/epoch - 8ms/step
# Epoch 424/1000
# 88/88 - 1s - loss: 21.2308 - val_loss: 37.4466 - 720ms/epoch - 8ms/step
# Epoch 425/1000
# 88/88 - 1s - loss: 21.1342 - val_loss: 37.3157 - 732ms/epoch - 8ms/step
# Epoch 426/1000
# 88/88 - 1s - loss: 21.0207 - val_loss: 39.0290 - 717ms/epoch - 8ms/step
# Epoch 427/1000
# 88/88 - 1s - loss: 21.2181 - val_loss: 37.7546 - 711ms/epoch - 8ms/step
# Epoch 428/1000
# 88/88 - 1s - loss: 21.3409 - val_loss: 38.2972 - 725ms/epoch - 8ms/step
# Epoch 429/1000
# 88/88 - 1s - loss: 21.1476 - val_loss: 37.7988 - 771ms/epoch - 9ms/step
# Epoch 430/1000
# 88/88 - 1s - loss: 21.1870 - val_loss: 37.6835 - 790ms/epoch - 9ms/step
# Epoch 431/1000
# 88/88 - 1s - loss: 21.6557 - val_loss: 38.0750 - 711ms/epoch - 8ms/step
# Epoch 432/1000
# 88/88 - 1s - loss: 21.3835 - val_loss: 37.8743 - 793ms/epoch - 9ms/step
# Epoch 433/1000
# 88/88 - 1s - loss: 20.8927 - val_loss: 37.6840 - 737ms/epoch - 8ms/step
# Epoch 434/1000
# 88/88 - 1s - loss: 21.4060 - val_loss: 38.1865 - 801ms/epoch - 9ms/step
# Epoch 435/1000
# 88/88 - 1s - loss: 21.0737 - val_loss: 38.4745 - 800ms/epoch - 9ms/step
# Epoch 436/1000
# 88/88 - 1s - loss: 21.5167 - val_loss: 38.0840 - 797ms/epoch - 9ms/step
# Epoch 437/1000
# 88/88 - 1s - loss: 21.1924 - val_loss: 37.4737 - 739ms/epoch - 8ms/step
# Epoch 438/1000
# 88/88 - 1s - loss: 21.3480 - val_loss: 37.7789 - 742ms/epoch - 8ms/step
# Epoch 439/1000
# 88/88 - 1s - loss: 21.4439 - val_loss: 37.6078 - 785ms/epoch - 9ms/step
# Epoch 440/1000
# 88/88 - 1s - loss: 21.2582 - val_loss: 37.3662 - 723ms/epoch - 8ms/step
# Epoch 441/1000
# 88/88 - 1s - loss: 21.0633 - val_loss: 37.4447 - 725ms/epoch - 8ms/step
# Epoch 442/1000
# 88/88 - 1s - loss: 21.1097 - val_loss: 37.8048 - 714ms/epoch - 8ms/step
# Epoch 443/1000
# 88/88 - 1s - loss: 21.2569 - val_loss: 37.8818 - 716ms/epoch - 8ms/step
# Epoch 444/1000
# 88/88 - 1s - loss: 21.2328 - val_loss: 37.6059 - 782ms/epoch - 9ms/step
# Epoch 445/1000
# 88/88 - 1s - loss: 21.1735 - val_loss: 37.4643 - 761ms/epoch - 9ms/step
# Epoch 446/1000
# 88/88 - 1s - loss: 21.1347 - val_loss: 37.6678 - 737ms/epoch - 8ms/step
# Epoch 447/1000
# 88/88 - 1s - loss: 20.9278 - val_loss: 37.9240 - 714ms/epoch - 8ms/step
# Epoch 448/1000
# 88/88 - 1s - loss: 21.0216 - val_loss: 37.7656 - 715ms/epoch - 8ms/step
# Epoch 449/1000
# 88/88 - 1s - loss: 21.1941 - val_loss: 37.6122 - 743ms/epoch - 8ms/step
# Epoch 450/1000
# 88/88 - 1s - loss: 20.8806 - val_loss: 37.5044 - 793ms/epoch - 9ms/step
# Epoch 451/1000
# 88/88 - 1s - loss: 21.1450 - val_loss: 37.4789 - 816ms/epoch - 9ms/step
# Epoch 452/1000
# 88/88 - 1s - loss: 21.2207 - val_loss: 36.9916 - 739ms/epoch - 8ms/step
# Epoch 453/1000
# 88/88 - 1s - loss: 21.0227 - val_loss: 37.3535 - 764ms/epoch - 9ms/step
# Epoch 454/1000
# 88/88 - 1s - loss: 20.8843 - val_loss: 38.0511 - 799ms/epoch - 9ms/step
# Epoch 455/1000
# 88/88 - 1s - loss: 20.7854 - val_loss: 37.4173 - 748ms/epoch - 8ms/step
# Epoch 456/1000
# 88/88 - 1s - loss: 20.8312 - val_loss: 37.4611 - 742ms/epoch - 8ms/step
# Epoch 457/1000
# 88/88 - 1s - loss: 20.9977 - val_loss: 37.9690 - 761ms/epoch - 9ms/step
# Epoch 458/1000
# 88/88 - 1s - loss: 20.7357 - val_loss: 37.7496 - 784ms/epoch - 9ms/step
# Epoch 459/1000
# 88/88 - 1s - loss: 21.0088 - val_loss: 37.5823 - 717ms/epoch - 8ms/step
# Epoch 460/1000
# 88/88 - 1s - loss: 20.8090 - val_loss: 37.7004 - 778ms/epoch - 9ms/step
# Epoch 461/1000
# 88/88 - 1s - loss: 21.2124 - val_loss: 38.0305 - 801ms/epoch - 9ms/step
# Epoch 462/1000
# 88/88 - 1s - loss: 20.8674 - val_loss: 37.3371 - 717ms/epoch - 8ms/step
# Epoch 463/1000
# 88/88 - 1s - loss: 21.0587 - val_loss: 37.5324 - 791ms/epoch - 9ms/step
# Epoch 464/1000
# 88/88 - 1s - loss: 20.8844 - val_loss: 37.1845 - 742ms/epoch - 8ms/step
# Epoch 465/1000
# 88/88 - 1s - loss: 21.0991 - val_loss: 37.7831 - 715ms/epoch - 8ms/step
# Epoch 466/1000
# 88/88 - 1s - loss: 20.8652 - val_loss: 37.5602 - 738ms/epoch - 8ms/step
# Epoch 467/1000
# 88/88 - 1s - loss: 20.9167 - val_loss: 38.3529 - 745ms/epoch - 8ms/step
# Epoch 468/1000
# 88/88 - 1s - loss: 20.8292 - val_loss: 37.1129 - 708ms/epoch - 8ms/step
# Epoch 469/1000
# 88/88 - 1s - loss: 21.1156 - val_loss: 37.9480 - 726ms/epoch - 8ms/step
# Epoch 470/1000
# 88/88 - 1s - loss: 20.9641 - val_loss: 37.2663 - 706ms/epoch - 8ms/step
# Epoch 471/1000
# 88/88 - 1s - loss: 20.5299 - val_loss: 37.9316 - 695ms/epoch - 8ms/step
# Epoch 472/1000
# 88/88 - 1s - loss: 20.7785 - val_loss: 38.1857 - 692ms/epoch - 8ms/step
# Epoch 473/1000
# 88/88 - 1s - loss: 20.9529 - val_loss: 37.5012 - 688ms/epoch - 8ms/step
# Epoch 474/1000
# 88/88 - 1s - loss: 21.2738 - val_loss: 37.9538 - 685ms/epoch - 8ms/step
# Epoch 475/1000
# 88/88 - 1s - loss: 20.7878 - val_loss: 37.1098 - 697ms/epoch - 8ms/step
# Epoch 476/1000
# 88/88 - 1s - loss: 20.5833 - val_loss: 37.8633 - 779ms/epoch - 9ms/step
# Epoch 477/1000
# 88/88 - 1s - loss: 20.4969 - val_loss: 37.5157 - 712ms/epoch - 8ms/step
# Epoch 478/1000
# 88/88 - 1s - loss: 20.8609 - val_loss: 37.7134 - 728ms/epoch - 8ms/step
# Epoch 479/1000
# 88/88 - 1s - loss: 20.4834 - val_loss: 37.4332 - 734ms/epoch - 8ms/step
# Epoch 480/1000
# 88/88 - 1s - loss: 20.4008 - val_loss: 37.4083 - 794ms/epoch - 9ms/step
# Epoch 481/1000
# 88/88 - 1s - loss: 20.7686 - val_loss: 37.0592 - 717ms/epoch - 8ms/step
# Epoch 482/1000
# 88/88 - 1s - loss: 20.6098 - val_loss: 37.9273 - 716ms/epoch - 8ms/step
# Epoch 483/1000
# 88/88 - 1s - loss: 20.6210 - val_loss: 38.7835 - 720ms/epoch - 8ms/step
# Epoch 484/1000
# 88/88 - 1s - loss: 20.8573 - val_loss: 38.3468 - 719ms/epoch - 8ms/step
# Epoch 485/1000
# 88/88 - 1s - loss: 20.8808 - val_loss: 37.4354 - 692ms/epoch - 8ms/step
# Epoch 486/1000
# 88/88 - 1s - loss: 21.0113 - val_loss: 38.0624 - 739ms/epoch - 8ms/step
# Epoch 487/1000
# 88/88 - 1s - loss: 20.8773 - val_loss: 38.0472 - 750ms/epoch - 9ms/step
# Epoch 488/1000
# 88/88 - 1s - loss: 20.6483 - val_loss: 37.5374 - 737ms/epoch - 8ms/step
# Epoch 489/1000
# 88/88 - 1s - loss: 20.6543 - val_loss: 38.2846 - 746ms/epoch - 8ms/step
# Epoch 490/1000
# 88/88 - 1s - loss: 20.4816 - val_loss: 37.1603 - 736ms/epoch - 8ms/step
# Epoch 491/1000
# 88/88 - 1s - loss: 20.5784 - val_loss: 38.0700 - 781ms/epoch - 9ms/step
# Epoch 492/1000
# 88/88 - 1s - loss: 20.8617 - val_loss: 37.5205 - 770ms/epoch - 9ms/step
# Epoch 493/1000
# 88/88 - 1s - loss: 20.6893 - val_loss: 37.6217 - 716ms/epoch - 8ms/step
# Epoch 494/1000
# 88/88 - 1s - loss: 20.8540 - val_loss: 37.8189 - 754ms/epoch - 9ms/step
# Epoch 495/1000
# 88/88 - 1s - loss: 20.6269 - val_loss: 37.3170 - 721ms/epoch - 8ms/step
# Epoch 496/1000
# 88/88 - 1s - loss: 20.6994 - val_loss: 37.9162 - 737ms/epoch - 8ms/step
# Epoch 497/1000
# 88/88 - 1s - loss: 20.5314 - val_loss: 37.4043 - 723ms/epoch - 8ms/step
# Epoch 498/1000
# 88/88 - 1s - loss: 20.6448 - val_loss: 38.0642 - 723ms/epoch - 8ms/step
# Epoch 499/1000
# 88/88 - 1s - loss: 20.6937 - val_loss: 38.0419 - 702ms/epoch - 8ms/step
# Epoch 500/1000
# 88/88 - 1s - loss: 20.4826 - val_loss: 38.8322 - 752ms/epoch - 9ms/step
# Epoch 501/1000
# 88/88 - 1s - loss: 20.6828 - val_loss: 37.8865 - 798ms/epoch - 9ms/step
# Epoch 502/1000
# 88/88 - 1s - loss: 20.5498 - val_loss: 38.4390 - 743ms/epoch - 8ms/step
# Epoch 503/1000
# 88/88 - 1s - loss: 20.2678 - val_loss: 38.0572 - 711ms/epoch - 8ms/step
# Epoch 504/1000
# 88/88 - 1s - loss: 20.4150 - val_loss: 37.8541 - 777ms/epoch - 9ms/step
# Epoch 505/1000
# 88/88 - 1s - loss: 20.4633 - val_loss: 38.0182 - 743ms/epoch - 8ms/step
# Epoch 506/1000
# 88/88 - 1s - loss: 20.5029 - val_loss: 37.9043 - 728ms/epoch - 8ms/step
# Epoch 507/1000
# 88/88 - 1s - loss: 20.3632 - val_loss: 38.7868 - 727ms/epoch - 8ms/step
# Epoch 508/1000
# 88/88 - 1s - loss: 20.7242 - val_loss: 38.2769 - 740ms/epoch - 8ms/step
# Epoch 509/1000
# 88/88 - 1s - loss: 20.6861 - val_loss: 37.8109 - 711ms/epoch - 8ms/step
# Epoch 510/1000
# 88/88 - 1s - loss: 20.4034 - val_loss: 37.6563 - 791ms/epoch - 9ms/step
# Epoch 511/1000
# 88/88 - 1s - loss: 20.2207 - val_loss: 38.0102 - 713ms/epoch - 8ms/step
# Epoch 512/1000
# 88/88 - 1s - loss: 20.3138 - val_loss: 38.3890 - 687ms/epoch - 8ms/step
# Epoch 513/1000
# 88/88 - 1s - loss: 20.3644 - val_loss: 38.3825 - 730ms/epoch - 8ms/step
# Epoch 514/1000
# 88/88 - 1s - loss: 20.5495 - val_loss: 37.9911 - 679ms/epoch - 8ms/step
# Epoch 515/1000
# 88/88 - 1s - loss: 20.0574 - val_loss: 38.4467 - 694ms/epoch - 8ms/step
# Epoch 516/1000
# 88/88 - 1s - loss: 20.2168 - val_loss: 38.2971 - 737ms/epoch - 8ms/step
# Epoch 517/1000
# 88/88 - 1s - loss: 20.4975 - val_loss: 38.0998 - 681ms/epoch - 8ms/step
# Epoch 518/1000
# 88/88 - 1s - loss: 20.2145 - val_loss: 38.0009 - 729ms/epoch - 8ms/step
# Epoch 519/1000
# 88/88 - 1s - loss: 20.5031 - val_loss: 37.7353 - 723ms/epoch - 8ms/step
# Epoch 520/1000
# 88/88 - 1s - loss: 20.2443 - val_loss: 38.1252 - 780ms/epoch - 9ms/step
# Epoch 521/1000
# 88/88 - 1s - loss: 20.1919 - val_loss: 38.5848 - 738ms/epoch - 8ms/step
# Epoch 522/1000
# 88/88 - 1s - loss: 20.3190 - val_loss: 38.5547 - 730ms/epoch - 8ms/step
# Epoch 523/1000
# 88/88 - 1s - loss: 20.1292 - val_loss: 38.8335 - 721ms/epoch - 8ms/step
# Epoch 524/1000
# 88/88 - 1s - loss: 20.4143 - val_loss: 38.4000 - 738ms/epoch - 8ms/step
# Epoch 525/1000
# 88/88 - 1s - loss: 20.4738 - val_loss: 38.1546 - 753ms/epoch - 9ms/step
# Epoch 526/1000
# 88/88 - 1s - loss: 20.0963 - val_loss: 38.4831 - 750ms/epoch - 9ms/step
# Epoch 527/1000
# 88/88 - 1s - loss: 20.3134 - val_loss: 38.0856 - 797ms/epoch - 9ms/step
# Epoch 528/1000
# 88/88 - 1s - loss: 20.3518 - val_loss: 37.8286 - 808ms/epoch - 9ms/step
# Epoch 529/1000
# 88/88 - 1s - loss: 20.6553 - val_loss: 38.0887 - 779ms/epoch - 9ms/step
# Epoch 530/1000
# 88/88 - 1s - loss: 20.2812 - val_loss: 39.4312 - 722ms/epoch - 8ms/step
# Epoch 531/1000
# 88/88 - 1s - loss: 20.1559 - val_loss: 38.1710 - 789ms/epoch - 9ms/step
# Epoch 532/1000
# 88/88 - 1s - loss: 20.4698 - val_loss: 38.3360 - 722ms/epoch - 8ms/step
# Epoch 533/1000
# 88/88 - 1s - loss: 19.9839 - val_loss: 38.7508 - 741ms/epoch - 8ms/step
# Epoch 534/1000
# 88/88 - 1s - loss: 20.3338 - val_loss: 38.1155 - 731ms/epoch - 8ms/step
# Epoch 535/1000
# ...
# 88/88 - 1s - loss: 18.7513 - val_loss: 38.4755 - 798ms/epoch - 9ms/step
# Epoch 818/1000
# 88/88 - 1s - loss: 18.3559 - val_loss: 39.4555 - 784ms/epoch - 9ms/step
# Epoch 819/1000
# 88/88 - 1s - loss: 18.5522 - val_loss: 38.6639 - 819ms/epoch - 9ms/step
# Epoch 820/1000
# 88/88 - 1s - loss: 18.6314 - val_loss: 38.5319 - 753ms/epoch - 9ms/step
# Epoch 821/1000
# 88/88 - 1s - loss: 18.4174 - val_loss: 39.1836 - 752ms/epoch - 9ms/step
# Epoch 822/1000
# 88/88 - 1s - loss: 18.1658 - val_loss: 39.0498 - 738ms/epoch - 8ms/step
# Epoch 823/1000
# 88/88 - 1s - loss: 18.3862 - val_loss: 39.5251 - 744ms/epoch - 8ms/step
# Epoch 824/1000
# 88/88 - 1s - loss: 18.3265 - val_loss: 38.9875 - 779ms/epoch - 9ms/step
# Epoch 825/1000
# 88/88 - 1s - loss: 18.2733 - val_loss: 39.1411 - 741ms/epoch - 8ms/step
# Epoch 826/1000
# 88/88 - 1s - loss: 18.4774 - val_loss: 38.5334 - 733ms/epoch - 8ms/step
# Epoch 827/1000
# 88/88 - 1s - loss: 18.5409 - val_loss: 38.3403 - 722ms/epoch - 8ms/step
# Epoch 828/1000
# 88/88 - 1s - loss: 18.2736 - val_loss: 39.0953 - 737ms/epoch - 8ms/step
# Epoch 829/1000
# 88/88 - 1s - loss: 18.1091 - val_loss: 39.0740 - 737ms/epoch - 8ms/step
# Epoch 830/1000
# 88/88 - 1s - loss: 18.2407 - val_loss: 38.9923 - 790ms/epoch - 9ms/step
# Epoch 831/1000
# 88/88 - 1s - loss: 18.2702 - val_loss: 38.5988 - 738ms/epoch - 8ms/step
# Epoch 832/1000
# 88/88 - 1s - loss: 18.2430 - val_loss: 38.4366 - 725ms/epoch - 8ms/step
# Epoch 833/1000
# 88/88 - 1s - loss: 18.2650 - val_loss: 39.0349 - 795ms/epoch - 9ms/step
# Epoch 834/1000
# 88/88 - 1s - loss: 18.2816 - val_loss: 39.5552 - 809ms/epoch - 9ms/step
# Epoch 835/1000
# 88/88 - 1s - loss: 18.4468 - val_loss: 39.5634 - 813ms/epoch - 9ms/step
# Epoch 836/1000
# 88/88 - 1s - loss: 18.1816 - val_loss: 39.3415 - 782ms/epoch - 9ms/step
# Epoch 837/1000
# 88/88 - 1s - loss: 18.2740 - val_loss: 38.7316 - 721ms/epoch - 8ms/step
# Epoch 838/1000
# 88/88 - 1s - loss: 17.9865 - val_loss: 39.3686 - 797ms/epoch - 9ms/step
# Epoch 839/1000
# 88/88 - 1s - loss: 18.3111 - val_loss: 39.1400 - 789ms/epoch - 9ms/step
# Epoch 840/1000
# 88/88 - 1s - loss: 18.5000 - val_loss: 39.2318 - 737ms/epoch - 8ms/step
# Epoch 841/1000
# 88/88 - 1s - loss: 18.3224 - val_loss: 39.3899 - 743ms/epoch - 8ms/step
# Epoch 842/1000
# 88/88 - 1s - loss: 18.6179 - val_loss: 38.7760 - 752ms/epoch - 9ms/step
# Epoch 843/1000
# 88/88 - 1s - loss: 18.5845 - val_loss: 39.6546 - 762ms/epoch - 9ms/step
# Epoch 844/1000
# 88/88 - 1s - loss: 18.4871 - val_loss: 39.2096 - 790ms/epoch - 9ms/step
# Epoch 845/1000
# 88/88 - 1s - loss: 18.1722 - val_loss: 39.0057 - 754ms/epoch - 9ms/step
# Epoch 846/1000
# 88/88 - 1s - loss: 18.2466 - val_loss: 39.4532 - 809ms/epoch - 9ms/step
# Epoch 847/1000
# 88/88 - 1s - loss: 18.1549 - val_loss: 39.1175 - 767ms/epoch - 9ms/step
# Epoch 848/1000
# 88/88 - 1s - loss: 18.5192 - val_loss: 39.1379 - 750ms/epoch - 9ms/step
# Epoch 849/1000
# 88/88 - 1s - loss: 18.2763 - val_loss: 38.8714 - 819ms/epoch - 9ms/step
# Epoch 850/1000
# 88/88 - 1s - loss: 18.6429 - val_loss: 39.7305 - 757ms/epoch - 9ms/step
# Epoch 851/1000
# 88/88 - 1s - loss: 18.4120 - val_loss: 39.4909 - 834ms/epoch - 9ms/step
# Epoch 852/1000
# 88/88 - 1s - loss: 18.3870 - val_loss: 38.9435 - 811ms/epoch - 9ms/step
# Epoch 853/1000
# 88/88 - 1s - loss: 18.4626 - val_loss: 39.5235 - 760ms/epoch - 9ms/step
# Epoch 854/1000
# 88/88 - 1s - loss: 18.2469 - val_loss: 39.2697 - 745ms/epoch - 8ms/step
# Epoch 855/1000
# 88/88 - 1s - loss: 17.9242 - val_loss: 39.4851 - 770ms/epoch - 9ms/step
# Epoch 856/1000
# 88/88 - 1s - loss: 18.1324 - val_loss: 39.0435 - 770ms/epoch - 9ms/step
# Epoch 857/1000
# 88/88 - 1s - loss: 18.1478 - val_loss: 39.3436 - 828ms/epoch - 9ms/step
# Epoch 858/1000
# 88/88 - 1s - loss: 18.0831 - val_loss: 39.1936 - 752ms/epoch - 9ms/step
# Epoch 859/1000
# 88/88 - 1s - loss: 18.1107 - val_loss: 39.0299 - 812ms/epoch - 9ms/step
# Epoch 860/1000
# 88/88 - 1s - loss: 18.5063 - val_loss: 38.8131 - 760ms/epoch - 9ms/step
# Epoch 861/1000
# 88/88 - 1s - loss: 18.1995 - val_loss: 39.3638 - 769ms/epoch - 9ms/step
# Epoch 862/1000
# 88/88 - 1s - loss: 18.2589 - val_loss: 39.1085 - 763ms/epoch - 9ms/step
# Epoch 863/1000
# 88/88 - 1s - loss: 18.1714 - val_loss: 39.1043 - 747ms/epoch - 8ms/step
# Epoch 864/1000
# 88/88 - 1s - loss: 18.4537 - val_loss: 39.1166 - 740ms/epoch - 8ms/step
# Epoch 865/1000
# 88/88 - 1s - loss: 18.5534 - val_loss: 38.5146 - 751ms/epoch - 9ms/step
# Epoch 866/1000
# 88/88 - 1s - loss: 18.2375 - val_loss: 39.3303 - 754ms/epoch - 9ms/step
# Epoch 867/1000
# 88/88 - 1s - loss: 18.1125 - val_loss: 39.2361 - 813ms/epoch - 9ms/step
# Epoch 868/1000
# 88/88 - 1s - loss: 17.9626 - val_loss: 39.5758 - 757ms/epoch - 9ms/step
# Epoch 869/1000
# 88/88 - 1s - loss: 17.9232 - val_loss: 38.4632 - 752ms/epoch - 9ms/step
# Epoch 870/1000
# 88/88 - 1s - loss: 18.1380 - val_loss: 39.4194 - 796ms/epoch - 9ms/step
# Epoch 871/1000
# 88/88 - 1s - loss: 18.3379 - val_loss: 38.9177 - 809ms/epoch - 9ms/step
# Epoch 872/1000
# 88/88 - 1s - loss: 18.2368 - val_loss: 39.4237 - 729ms/epoch - 8ms/step
# Epoch 873/1000
# 88/88 - 1s - loss: 18.0562 - val_loss: 39.4058 - 776ms/epoch - 9ms/step
# Epoch 874/1000
# 88/88 - 1s - loss: 18.0699 - val_loss: 39.2147 - 755ms/epoch - 9ms/step
# Epoch 875/1000
# 88/88 - 1s - loss: 18.1328 - val_loss: 38.8237 - 738ms/epoch - 8ms/step
# Epoch 876/1000
# 88/88 - 1s - loss: 17.9862 - val_loss: 39.1309 - 743ms/epoch - 8ms/step
# Epoch 877/1000
# 88/88 - 1s - loss: 18.2831 - val_loss: 39.4420 - 826ms/epoch - 9ms/step
# Epoch 878/1000
# 88/88 - 1s - loss: 18.0353 - val_loss: 39.1621 - 800ms/epoch - 9ms/step
# Epoch 879/1000
# 88/88 - 1s - loss: 18.2261 - val_loss: 39.3718 - 814ms/epoch - 9ms/step
# Epoch 880/1000
# 88/88 - 1s - loss: 18.2885 - val_loss: 38.7362 - 757ms/epoch - 9ms/step
# Epoch 881/1000
# 88/88 - 1s - loss: 18.1553 - val_loss: 38.5814 - 757ms/epoch - 9ms/step
# Epoch 882/1000
# 88/88 - 1s - loss: 18.1911 - val_loss: 38.6344 - 746ms/epoch - 8ms/step
# Epoch 883/1000
# 88/88 - 1s - loss: 17.8131 - val_loss: 39.1374 - 772ms/epoch - 9ms/step
# Epoch 884/1000
# 88/88 - 1s - loss: 18.3897 - val_loss: 38.6714 - 813ms/epoch - 9ms/step
# Epoch 885/1000
# 88/88 - 1s - loss: 17.5961 - val_loss: 39.1886 - 738ms/epoch - 8ms/step
# Epoch 886/1000
# 88/88 - 1s - loss: 17.9130 - val_loss: 38.9903 - 724ms/epoch - 8ms/step
# Epoch 887/1000
# 88/88 - 1s - loss: 18.0415 - val_loss: 39.0998 - 725ms/epoch - 8ms/step
# Epoch 888/1000
# 88/88 - 1s - loss: 18.2556 - val_loss: 39.3558 - 731ms/epoch - 8ms/step
# Epoch 889/1000
# 88/88 - 1s - loss: 18.0639 - val_loss: 38.6882 - 748ms/epoch - 8ms/step
# Epoch 890/1000
# 88/88 - 1s - loss: 17.8637 - val_loss: 39.4331 - 757ms/epoch - 9ms/step
# Epoch 891/1000
# 88/88 - 1s - loss: 17.8687 - val_loss: 39.0232 - 738ms/epoch - 8ms/step
# Epoch 892/1000
# 88/88 - 1s - loss: 17.9586 - val_loss: 38.2355 - 803ms/epoch - 9ms/step
# Epoch 893/1000
# 88/88 - 1s - loss: 18.2604 - val_loss: 39.5022 - 760ms/epoch - 9ms/step
# Epoch 894/1000
# 88/88 - 1s - loss: 17.9663 - val_loss: 38.7824 - 732ms/epoch - 8ms/step
# Epoch 895/1000
# 88/88 - 1s - loss: 17.7241 - val_loss: 39.0288 - 747ms/epoch - 8ms/step
# Epoch 896/1000
# 88/88 - 1s - loss: 17.9105 - val_loss: 39.2823 - 743ms/epoch - 8ms/step
# Epoch 897/1000
# 88/88 - 1s - loss: 18.1851 - val_loss: 38.7147 - 756ms/epoch - 9ms/step
# Epoch 898/1000
# 88/88 - 1s - loss: 17.9862 - val_loss: 39.1794 - 738ms/epoch - 8ms/step
# Epoch 899/1000
# 88/88 - 1s - loss: 18.4350 - val_loss: 39.7485 - 764ms/epoch - 9ms/step
# Epoch 900/1000
# 88/88 - 1s - loss: 18.1310 - val_loss: 39.3630 - 721ms/epoch - 8ms/step
# Epoch 901/1000
# 88/88 - 1s - loss: 17.8703 - val_loss: 39.4901 - 730ms/epoch - 8ms/step
# Epoch 902/1000
# 88/88 - 1s - loss: 18.0713 - val_loss: 38.8919 - 710ms/epoch - 8ms/step
# Epoch 903/1000
# 88/88 - 1s - loss: 18.2080 - val_loss: 39.3589 - 716ms/epoch - 8ms/step
# Epoch 904/1000
# 88/88 - 1s - loss: 17.7231 - val_loss: 38.8765 - 727ms/epoch - 8ms/step
# Epoch 905/1000
# 88/88 - 1s - loss: 17.9421 - val_loss: 38.6554 - 721ms/epoch - 8ms/step
# Epoch 906/1000
# 88/88 - 1s - loss: 17.9039 - val_loss: 39.2656 - 726ms/epoch - 8ms/step
# Epoch 907/1000
# 88/88 - 1s - loss: 18.1089 - val_loss: 38.5287 - 709ms/epoch - 8ms/step
# Epoch 908/1000
# 88/88 - 1s - loss: 17.9165 - val_loss: 39.2804 - 704ms/epoch - 8ms/step
# Epoch 909/1000
# 88/88 - 1s - loss: 17.9718 - val_loss: 39.1364 - 705ms/epoch - 8ms/step
# Epoch 910/1000
# 88/88 - 1s - loss: 17.7349 - val_loss: 38.7890 - 709ms/epoch - 8ms/step
# Epoch 911/1000
# 88/88 - 1s - loss: 18.1851 - val_loss: 38.7539 - 706ms/epoch - 8ms/step
# Epoch 912/1000
# 88/88 - 1s - loss: 17.9325 - val_loss: 39.3686 - 772ms/epoch - 9ms/step
# Epoch 913/1000
# 88/88 - 1s - loss: 17.8853 - val_loss: 39.1080 - 734ms/epoch - 8ms/step
# Epoch 914/1000
# 88/88 - 1s - loss: 18.1138 - val_loss: 38.7706 - 770ms/epoch - 9ms/step
# Epoch 915/1000
# 88/88 - 1s - loss: 17.8641 - val_loss: 38.8263 - 783ms/epoch - 9ms/step
# Epoch 916/1000
# 88/88 - 1s - loss: 17.9121 - val_loss: 38.9954 - 779ms/epoch - 9ms/step
# Epoch 917/1000
# 88/88 - 1s - loss: 18.1751 - val_loss: 39.2847 - 771ms/epoch - 9ms/step
# Epoch 918/1000
# 88/88 - 1s - loss: 17.6014 - val_loss: 39.8974 - 743ms/epoch - 8ms/step
# Epoch 919/1000
# 88/88 - 1s - loss: 17.7704 - val_loss: 39.2366 - 738ms/epoch - 8ms/step
# Epoch 920/1000
# 88/88 - 1s - loss: 17.9796 - val_loss: 40.2093 - 789ms/epoch - 9ms/step
# Epoch 921/1000
# 88/88 - 1s - loss: 17.8643 - val_loss: 39.3696 - 734ms/epoch - 8ms/step
# Epoch 922/1000
# 88/88 - 1s - loss: 17.9927 - val_loss: 40.0602 - 733ms/epoch - 8ms/step
# Epoch 923/1000
# 88/88 - 1s - loss: 18.1492 - val_loss: 39.1574 - 728ms/epoch - 8ms/step
# Epoch 924/1000
# 88/88 - 1s - loss: 18.3400 - val_loss: 39.4433 - 781ms/epoch - 9ms/step
# Epoch 925/1000
# 88/88 - 1s - loss: 17.9345 - val_loss: 39.3503 - 789ms/epoch - 9ms/step
# Epoch 926/1000
# 88/88 - 1s - loss: 17.8788 - val_loss: 39.2673 - 727ms/epoch - 8ms/step
# Epoch 927/1000
# 88/88 - 1s - loss: 17.8661 - val_loss: 39.5732 - 790ms/epoch - 9ms/step
# Epoch 928/1000
# 88/88 - 1s - loss: 17.7304 - val_loss: 39.7571 - 786ms/epoch - 9ms/step
# Epoch 929/1000
# 88/88 - 1s - loss: 17.8270 - val_loss: 39.8537 - 724ms/epoch - 8ms/step
# Epoch 930/1000
# 88/88 - 1s - loss: 17.9668 - val_loss: 39.8178 - 739ms/epoch - 8ms/step
# Epoch 931/1000
# 88/88 - 1s - loss: 18.0841 - val_loss: 39.0742 - 732ms/epoch - 8ms/step
# Epoch 932/1000
# 88/88 - 1s - loss: 17.8217 - val_loss: 38.9633 - 735ms/epoch - 8ms/step
# Epoch 933/1000
# 88/88 - 1s - loss: 17.5622 - val_loss: 39.3143 - 728ms/epoch - 8ms/step
# Epoch 934/1000
# 88/88 - 1s - loss: 17.8109 - val_loss: 39.1342 - 745ms/epoch - 8ms/step
# Epoch 935/1000
# 88/88 - 1s - loss: 17.8745 - val_loss: 38.9901 - 734ms/epoch - 8ms/step
# Epoch 936/1000
# 88/88 - 1s - loss: 17.7494 - val_loss: 38.9571 - 723ms/epoch - 8ms/step
# Epoch 937/1000
# 88/88 - 1s - loss: 17.5817 - val_loss: 38.8997 - 721ms/epoch - 8ms/step
# Epoch 938/1000
# 88/88 - 1s - loss: 17.8183 - val_loss: 39.0647 - 736ms/epoch - 8ms/step
# Epoch 939/1000
# 88/88 - 1s - loss: 17.9156 - val_loss: 38.7070 - 742ms/epoch - 8ms/step
# Epoch 940/1000
# 88/88 - 1s - loss: 17.8081 - val_loss: 39.2023 - 731ms/epoch - 8ms/step
# Epoch 941/1000
# 88/88 - 1s - loss: 17.6131 - val_loss: 39.2684 - 716ms/epoch - 8ms/step
# Epoch 942/1000
# 88/88 - 1s - loss: 17.9517 - val_loss: 38.9744 - 723ms/epoch - 8ms/step
# Epoch 943/1000
# 88/88 - 1s - loss: 17.6873 - val_loss: 39.3656 - 726ms/epoch - 8ms/step
# Epoch 944/1000
# 88/88 - 1s - loss: 17.7810 - val_loss: 39.3337 - 728ms/epoch - 8ms/step
# Epoch 945/1000
# 88/88 - 1s - loss: 18.1773 - val_loss: 38.6089 - 757ms/epoch - 9ms/step
# Epoch 946/1000
# 88/88 - 1s - loss: 17.7313 - val_loss: 39.4388 - 752ms/epoch - 9ms/step
# Epoch 947/1000
# 88/88 - 1s - loss: 17.9434 - val_loss: 39.8040 - 736ms/epoch - 8ms/step
# Epoch 948/1000
# 88/88 - 1s - loss: 17.7622 - val_loss: 39.6847 - 791ms/epoch - 9ms/step
# Epoch 949/1000
# 88/88 - 1s - loss: 17.6784 - val_loss: 39.5927 - 720ms/epoch - 8ms/step
# Epoch 950/1000
# 88/88 - 1s - loss: 17.6707 - val_loss: 39.0595 - 792ms/epoch - 9ms/step
# Epoch 951/1000
# 88/88 - 1s - loss: 17.7675 - val_loss: 39.0748 - 714ms/epoch - 8ms/step
# Epoch 952/1000
# 88/88 - 1s - loss: 18.2099 - val_loss: 39.0524 - 721ms/epoch - 8ms/step
# Epoch 953/1000
# 88/88 - 1s - loss: 17.9771 - val_loss: 39.8885 - 742ms/epoch - 8ms/step
# Epoch 954/1000
# 88/88 - 1s - loss: 17.7127 - val_loss: 39.0068 - 825ms/epoch - 9ms/step
# Epoch 955/1000
# 88/88 - 1s - loss: 17.7358 - val_loss: 39.6005 - 777ms/epoch - 9ms/step
# Epoch 956/1000
# 88/88 - 1s - loss: 17.6056 - val_loss: 39.6046 - 794ms/epoch - 9ms/step
# Epoch 957/1000
# 88/88 - 1s - loss: 17.6042 - val_loss: 39.6288 - 742ms/epoch - 8ms/step
# Epoch 958/1000
# 88/88 - 1s - loss: 17.7556 - val_loss: 39.5917 - 738ms/epoch - 8ms/step
# Epoch 959/1000
# 88/88 - 1s - loss: 17.6369 - val_loss: 39.7481 - 730ms/epoch - 8ms/step
# Epoch 960/1000
# 88/88 - 1s - loss: 17.6480 - val_loss: 39.9264 - 803ms/epoch - 9ms/step
# Epoch 961/1000
# 88/88 - 1s - loss: 17.6389 - val_loss: 39.3364 - 760ms/epoch - 9ms/step
# Epoch 962/1000
# 88/88 - 1s - loss: 17.8787 - val_loss: 39.1771 - 799ms/epoch - 9ms/step
# Epoch 963/1000
# 88/88 - 1s - loss: 17.5460 - val_loss: 38.8803 - 734ms/epoch - 8ms/step
# Epoch 964/1000
# 88/88 - 1s - loss: 17.8725 - val_loss: 39.2006 - 784ms/epoch - 9ms/step
# Epoch 965/1000
# 88/88 - 1s - loss: 17.5581 - val_loss: 39.2513 - 724ms/epoch - 8ms/step
# Epoch 966/1000
# 88/88 - 1s - loss: 17.6392 - val_loss: 39.4379 - 721ms/epoch - 8ms/step
# Epoch 967/1000
# 88/88 - 1s - loss: 17.4773 - val_loss: 39.0875 - 711ms/epoch - 8ms/step
# Epoch 968/1000
# 88/88 - 1s - loss: 17.7420 - val_loss: 38.8401 - 778ms/epoch - 9ms/step
# Epoch 969/1000
# 88/88 - 1s - loss: 17.5025 - val_loss: 39.4224 - 731ms/epoch - 8ms/step
# Epoch 970/1000
# 88/88 - 1s - loss: 17.8869 - val_loss: 39.7435 - 719ms/epoch - 8ms/step
# Epoch 971/1000
# 88/88 - 1s - loss: 17.5741 - val_loss: 39.5075 - 710ms/epoch - 8ms/step
# Epoch 972/1000
# 88/88 - 1s - loss: 17.6415 - val_loss: 39.1964 - 722ms/epoch - 8ms/step
# Epoch 973/1000
# 88/88 - 1s - loss: 18.0617 - val_loss: 39.4800 - 704ms/epoch - 8ms/step
# Epoch 974/1000
# 88/88 - 1s - loss: 18.0894 - val_loss: 40.1500 - 708ms/epoch - 8ms/step
# Epoch 975/1000
# 88/88 - 1s - loss: 17.4353 - val_loss: 39.7203 - 762ms/epoch - 9ms/step
# Epoch 976/1000
# 88/88 - 1s - loss: 17.4757 - val_loss: 39.4266 - 783ms/epoch - 9ms/step
# Epoch 977/1000
# 88/88 - 1s - loss: 17.6866 - val_loss: 39.1007 - 707ms/epoch - 8ms/step
# Epoch 978/1000
# 88/88 - 1s - loss: 17.8715 - val_loss: 39.1993 - 781ms/epoch - 9ms/step
# Epoch 979/1000
# 88/88 - 1s - loss: 17.3682 - val_loss: 39.5677 - 796ms/epoch - 9ms/step
# Epoch 980/1000
# 88/88 - 1s - loss: 17.6847 - val_loss: 39.1541 - 826ms/epoch - 9ms/step
# Epoch 981/1000
# 88/88 - 1s - loss: 17.7050 - val_loss: 38.9883 - 773ms/epoch - 9ms/step
# Epoch 982/1000
# 88/88 - 1s - loss: 17.6678 - val_loss: 39.4162 - 731ms/epoch - 8ms/step
# Epoch 983/1000
# 88/88 - 1s - loss: 17.9372 - val_loss: 39.5349 - 734ms/epoch - 8ms/step
# Epoch 984/1000
# 88/88 - 1s - loss: 17.8412 - val_loss: 39.8103 - 722ms/epoch - 8ms/step
# Epoch 985/1000
# 88/88 - 1s - loss: 17.5025 - val_loss: 39.3250 - 741ms/epoch - 8ms/step
# Epoch 986/1000
# 88/88 - 1s - loss: 17.6306 - val_loss: 39.7570 - 731ms/epoch - 8ms/step
# Epoch 987/1000
# 88/88 - 1s - loss: 17.5247 - val_loss: 39.7914 - 752ms/epoch - 9ms/step
# Epoch 988/1000
# 88/88 - 1s - loss: 17.7174 - val_loss: 39.4694 - 738ms/epoch - 8ms/step
# Epoch 989/1000
# 88/88 - 1s - loss: 17.8022 - val_loss: 39.3690 - 788ms/epoch - 9ms/step
# Epoch 990/1000
# 88/88 - 1s - loss: 17.5772 - val_loss: 38.9763 - 744ms/epoch - 8ms/step
# Epoch 991/1000
# 88/88 - 1s - loss: 17.5691 - val_loss: 38.9545 - 800ms/epoch - 9ms/step
# Epoch 992/1000
# 88/88 - 1s - loss: 17.5538 - val_loss: 39.2733 - 797ms/epoch - 9ms/step
# Epoch 993/1000
# 88/88 - 1s - loss: 17.5189 - val_loss: 39.3153 - 792ms/epoch - 9ms/step
# Epoch 994/1000
# 88/88 - 1s - loss: 17.3045 - val_loss: 39.6436 - 723ms/epoch - 8ms/step
# Epoch 995/1000
# 88/88 - 1s - loss: 17.3923 - val_loss: 39.5823 - 735ms/epoch - 8ms/step
# Epoch 996/1000
# 88/88 - 1s - loss: 17.2703 - val_loss: 39.8452 - 715ms/epoch - 8ms/step
# Epoch 997/1000
# 88/88 - 1s - loss: 17.3542 - val_loss: 39.7194 - 733ms/epoch - 8ms/step
# Epoch 998/1000
# 88/88 - 1s - loss: 17.4644 - val_loss: 39.3425 - 737ms/epoch - 8ms/step
# Epoch 999/1000
# 88/88 - 1s - loss: 17.4622 - val_loss: 39.3738 - 736ms/epoch - 8ms/step
# Epoch 1000/1000
# 88/88 - 1s - loss: 17.5308 - val_loss: 39.2211 - 731ms/epoch - 8ms/step

# %%
history

# %%
# preds = grid_search.predict(X_test)
preds = model.predict(df_test)
# Out:
# 38/38 - 0s - 181ms/epoch - 5ms/step

# %%
r2_score(y_test, preds)
# Out:
# 0.3170235267501975

# %%
mean_squared_error(y_test, preds)
# Out:
# 39.22107248433494

# %%
mean_absolute_error(y_test, preds)
# Out:
# 3.9889039252026057

# %% [markdown]
# Let's dig into the predictions a little bit

# %%
df_preds = pd.DataFrame(y_test)

# %%
df_preds['LogPredicted'] = preds
df_preds['Predicted'] = (np.exp(df_preds['LogPredicted']) - 10).round(2)
df_preds['Target'] = (np.exp(df_preds['FantasyPointsPPR']) - 10).round(2)
df_preds.sample(20)
# Out:
#        FantasyPointsPPR  LogPredicted     Predicted        Target
# 31114             12.00     12.230705  2.049777e+05  1.627448e+05
# 28933              2.30      0.964936 -7.380000e+00 -3.000000e-02
# 24107              0.00      0.377474 -8.540000e+00 -9.000000e+00
# 25204              0.00      6.800120  8.879600e+02 -9.000000e+00
# 23117              8.68      1.439788 -5.780000e+00  5.874050e+03
# 30520              0.00      3.605809  2.681000e+01 -9.000000e+00
# 28826             10.90      1.467511 -5.660000e+00  5.416636e+04
# 28570              0.00      0.514041 -8.330000e+00 -9.000000e+00
# 27742             12.20     10.864594  5.228178e+04  1.987791e+05
# 32005              0.00      2.076699 -2.020000e+00 -9.000000e+00
# 23198              5.70      3.142683  1.317000e+01  2.888700e+02
# 28188             17.70      6.212607  4.890000e+02  4.864209e+07
# 24411              3.60      1.803802 -3.930000e+00  2.660000e+01
# 22893              0.00      0.504288 -8.340000e+00 -9.000000e+00
# 30856              1.50      0.687878 -8.010000e+00 -5.520000e+00
# 27440              0.00     13.334532  6.181680e+05 -9.000000e+00
# 26768              4.80      5.537056  2.439300e+02  1.115100e+02
# 27110             16.66     20.427750  7.441473e+08  1.719277e+07
# 31994              0.00      0.650786 -8.080000e+00 -9.000000e+00
# 27605             29.52     17.949188  6.240701e+07  6.612613e+12

# %%
r2_score(df_preds['Target'], df_preds['Predicted'])
# Out:
# -0.00014346997439562692

# %%
mean_squared_error(df_preds['Target'], df_preds['Predicted'])
# Out:
# 2.1023546190736247e+46

# %%
mean_absolute_error(df_preds['Target'], df_preds['Predicted'])
# Out:
# 1.7366101910201196e+21

# %% [markdown]
# # Time to do some digging to see where the model fails

# %%
df_review = X_test
df_review['Predicted'] = df_preds['Predicted']
df_review['Target'] = df_preds['Target']
df_review['Error'] = df_review['Target'] - df_review['Predicted']
df_review.head()
# Out:
#        Unnamed: 0  Unnamed: 0.1    GameKey  ...  Predicted Target Error
# 22432       22432          1348  202011028  ...      -5.37   -9.0 -3.63
# 22433       22433          1351  202011028  ...      -8.33   -9.0 -0.67
# 22434       22434          1354  202011028  ...      -5.12   -9.0 -3.88
# 22435       22435          1363  202011032  ...      -7.93   -9.0 -1.07
# 22436       22436          1368  202011032  ...      -8.45   -9.0 -0.55
#
# [5 rows x 69 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Let's visualize how the prediction error varies by player position.

plt.figure(figsize = (12, 9))
sns.violinplot(x = df_review['Position'],
               y = df_review['Error'])

# %% [markdown]
# From the above plot we can see that for the bulk of positions, the error is quite tightly distributed around a mean of 0.  However, with kickers we can see that the error is more widely spread.  <br> In all cases, the error is skewed to being more positive than negative.

# %%
# Let's apply our engineered features to df_review and keep on digging
df_review = trailing_stats_mean(df_review)
df_review['PlayerTier'] = df_review.apply(lambda x: tier_maker(x['Position'], x['TAFantasyPointsPPR']), axis = 1)
df_review['AbsoluteError'] = abs(df_review['Error'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TAFantasyPointsPPR'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-df988d34864b> in <module>()
#       1 # Let's apply our engineered features to df_review and keep on digging
#       2 df_review = trailing_stats_mean(df_review)
# ----> 3 df_review['PlayerTier'] = df_review.apply(lambda x: tier_maker(x['Position'], x['TAFantasyPointsPPR']), axis = 1)
#       4 df_review['AbsoluteError'] = abs(df_review['Error'])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7763             kwds=kwds,
#    7764         )
# -> 7765         return op.get_result()
#    7766
#    7767     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
#     187     def apply_empty_result(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply_standard(self)
#     274
#     275     def apply_standard(self):
# --> 276         results, res_index = self.apply_series_generator()
#     277
#     278         # wrap results
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#     288             for i, v in enumerate(series_gen):
#     289                 # ignore SettingWithCopy here in case the user mutates
# --> 290                 results[i] = self.f(v)
#     291                 if isinstance(results[i], ABCSeries):
#     292                     # If we have a view on v, we need to make a copy because
#
# <ipython-input-38-df988d34864b> in <lambda>(x)
#       1 # Let's apply our engineered features to df_review and keep on digging
#       2 df_review = trailing_stats_mean(df_review)
# ----> 3 df_review['PlayerTier'] = df_review.apply(lambda x: tier_maker(x['Position'], x['TAFantasyPointsPPR']), axis = 1)
#       4 df_review['AbsoluteError'] = abs(df_review['Error'])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in __getitem__(self, key)
#     822
#     823         elif key_is_scalar:
# --> 824             return self._get_value(key)
#     825
#     826         if is_hashable(key):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in _get_value(self, label, takeable)
#     930
#     931         # Similar to Index.get_value, but we do not fall back to positional
# --> 932         loc = self.index.get_loc(label)
#     933         return self.index._get_values_for_loc(self, loc, label)
#     934
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'TAFantasyPointsPPR'

# %%
mean_tier_error = df_review[['PlayerTier', 'Error', 'AbsoluteError']].groupby('PlayerTier').mean()
sum_tier_error = df_review[['PlayerTier', 'Error','AbsoluteError']].groupby('PlayerTier').sum()
count_tier_error = df_review[['PlayerTier', 'Error']].groupby('PlayerTier').count()
mean_tier_error['Total Absolute Error'] = sum_tier_error['AbsoluteError']
mean_tier_error['Total Error'] = sum_tier_error['Error']
mean_tier_error['Error Count'] = count_tier_error['Error']
mean_tier_error.rename({'Error': 'Mean Error'}, 
                       axis = 1)
